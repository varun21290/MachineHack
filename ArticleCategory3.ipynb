# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy as sp
from nltk.corpus import stopwords
import re
from textblob import Word
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn_pandas import DataFrameMapper
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.metrics import f1_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
from textblob import TextBlob

# %%
data_path = './data'

# %%
raw_data_test = pd.read_excel(data_path + '/Data_Test.xlsx')
raw_data_train = pd.read_excel(data_path + '/Data_Train.xlsx')

# %%
raw_data_test.shape
# Out:
# (2748, 1)

# %%
raw_data_train.shape
# Out:
# (7628, 2)

# %%
raw_data_train['count'] = raw_data_train.groupby('STORY')['STORY'].transform(np.size)

# %%
raw_data_train = raw_data_train.loc[raw_data_train['count'] == 1]

# %%
split = raw_data_train.shape[0]

# %%
split
# Out:
# 7499

# %%
data_under_processing = pd.concat([raw_data_train,raw_data_test],sort=False)

# %%
processed_data['STORY'] = data_under_processing['STORY']

# %%
processed_data['word_count'] = data_under_processing['STORY'].apply(lambda x: len(x.split(' ')))

# %%
def avg_word(sentence):
  words = sentence.split()
  return (sum(len(word) for word in words)/len(words))
processed_data['avg_word_length'] = processed_data['STORY'].apply(lambda x: avg_word(x))

# %%
processed_data['char_count'] = processed_data['STORY'].apply(len)
processed_data['word_density'] = processed_data['char_count'] / (processed_data['word_count']+1)

# %%
processed_data['STORY'] = processed_data['STORY'].apply(lambda x: " ".join(x.lower() for x in x.split()))

# %%
processed_data['STORY'] = processed_data['STORY'].replace('[^\w\s]','')

# %%
stop = stopwords.words('english')

# %%
processed_data['STORY'] = processed_data['STORY'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))

# %%
processed_data['STORY'] = processed_data['STORY'].apply(lambda x: re.sub('[^a-zA-Z \n\.]', ' ', x))
processed_data['STORY'] = processed_data['STORY'].apply(lambda x: re.sub('[.]', ' ', x))

# %%
processed_data['STORY_LEM'] = processed_data['STORY'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))

# %%
processed_data['STORY_LEM2'] = processed_data['STORY_LEM'].apply(lambda x: " ".join(x for x in x.split() if len(x) > 2))

# %%
rare_freq = pd.Series(' '.join(processed_data['STORY_LEM2']).split()).value_counts()[-10000:]
rare_freq = list(rare_freq.index)
processed_data['STORY_LEM2'] = processed_data['STORY_LEM2'].apply(lambda x: " ".join(x for x in x.split() if x not in rare_freq))

# %%
def specific_pos_tag(x, flag):
    string = ''
    try:
        wiki = TextBlob(x)
        for tup in wiki.tags:
            ppo = list(tup)[1]
            if ppo in pos_family[flag]:
                string = string + ' ' + list(tup)[0] 
    except:
        pass
    return string

# %%
pos_family = {
    'noun' : ['NN','NNS','NNP','NNPS'],
    'pron' : ['PRP','PRP$','WP','WP$'],
    'verb' : ['VB','VBD','VBG','VBN','VBP','VBZ'],
    'adj' :  ['JJ','JJR','JJS'],
    'adv' : ['RB','RBR','RBS','WRB']
}

# %%
processed_data['noun_String'] = processed_data['STORY_LEM2'].apply(lambda x: specific_pos_tag(x, 'noun'))

# %%
processed_data['adj_String'] = processed_data['STORY_LEM2'].apply(lambda x: specific_pos_tag(x, 'adj'))
processed_data['adv_String'] = processed_data['STORY_LEM2'].apply(lambda x: specific_pos_tag(x, 'adv'))

# %%
rare_freq = pd.Series(' '.join(processed_data['adj_String']).split()).value_counts()[-3400:]
rare_freq = list(rare_freq.index)
processed_data['adj_String'] = processed_data['adj_String'].apply(lambda x: " ".join(x for x in x.split() if x not in rare_freq))
rare_freq = pd.Series(' '.join(processed_data['adv_String']).split()).value_counts()[-1000:]
rare_freq = list(rare_freq.index)
processed_data['adv_String'] = processed_data['adv_String'].apply(lambda x: " ".join(x for x in x.split() if x not in rare_freq))

# %%
rare_freq = pd.Series(' '.join(processed_data['noun_String']).split()).value_counts()[-2800:]
rare_freq = list(rare_freq.index)
processed_data['noun_String'] = processed_data['noun_String'].apply(lambda x: " ".join(x for x in x.split() if x not in rare_freq))

# %%
processed_data['noun_adj_adv_string'] = processed_data['noun_String'] + ' ' + processed_data['adj_String'] + ' ' + processed_data['adv_String']

# %%
processed_data['noun_adj_string'] = processed_data['noun_String'] + ' ' + processed_data['adj_String']

# %%
processed_data.to_csv(data_path + '/process_data3.csv')

# %%
ready_data = processed_data
# ready_data['SECTION'] = processed_data['SECTION']

# %%
# ready_data = ready_data.drop(columns=['STORY','count','STORY_LEM'])
ready_data.head()
# Out:
#    SECTION  word_count  avg_word_length  char_count  word_density  \
# 0      3.0         146                4         843      5.734694
# 1      0.0          17                6         129      7.166667
# 2      3.0          57                5         386      6.655172
# 3      1.0         101                4         587      5.754902
# 4      3.0          46                5         299      6.361702
#
#                                           STORY_LEM2  \
# 0  painful huge reversal fee income among private...
# 1  formidable opposition alliance among congress ...
# 2  asian currency trading lower today south korea...
# 3  want answer question click answer clicking ans...
# 4  global market gold price edged today disappoin...
#
#                                          noun_String
# 0   reversal income sector bank fee loan deal boo...
# 1   opposition alliance jharkhand mukti jharkhand...
# 2   currency today china china ringgit rupiah dol...
# 3   question click answer answer proceed answer v...
# 4   market gold price today factory activity data...

# %%
ready_data.head()
# Out:
#    SECTION  word_count  avg_word_length  char_count  word_density  \
# 0      3.0         146                4         843      5.734694
# 1      0.0          17                6         129      7.166667
# 2      3.0          57                5         386      6.655172
# 3      1.0         101                4         587      5.754902
# 4      3.0          46                5         299      6.361702
#
#                                           STORY_LEM2
# 0  painful huge reversal fee income among private...
# 1  formidable opposition alliance among congress ...
# 2  asian currency trading lower today south korea...
# 3  want answer question click answer clicking ans...
# 4  global market gold price edged today disappoin...

# %%
labels_train = ready_data[:split]['SECTION']

# %%
mapper = DataFrameMapper([
#     (list(ready_data.columns)[1:4],None),
    ('noun_String',CountVectorizer(binary=True, ngram_range=(0,1))),
#     ('noun_String',CountVectorizer(binary=True, ngram_range=(0,1))),
    ('noun_String',TfidfVectorizer(smooth_idf=True)),
    ('adj_String',CountVectorizer(binary=True, ngram_range=(0,1))),
#     ('noun_String',CountVectorizer(binary=True, ngram_range=(0,1))),
    ('adj_String',TfidfVectorizer(smooth_idf=True))
])

# %%
X_mapped = mapper.fit_transform(ready_data)

# %%
train_mapped,test_mapped = X_mapped[:split,:],X_mapped[split:,:]

# %%
X_train,X_test,Y_train,Y_test=train_test_split(train_mapped,labels_train,test_size=0.1,random_state=42)

# %%
from sklearn.neural_network import MLPClassifier

# %%
clf_neural = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(200,100), random_state=1)

# %%
clf_neural.fit(X_train,Y_train)
# Out:
# MLPClassifier(activation='relu', alpha=1e-05, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(200, 100), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=1, shuffle=True, solver='lbfgs', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %%
Y_pred_neural_train = clf_neural.predict(X_train)
print confusion_matrix(Y_pred_neural_train,Y_train)
print accuracy_score(Y_pred_neural_train,Y_train)
# Out:
# [[1499    0    0    0]
#  [   0 2447    0    0]
#  [   0    0 1714    0]
#  [   0    0    0 1089]]
# 1.0

# %%
Y_pred_neural_test = clf_neural.predict(X_test)
print confusion_matrix(Y_pred_neural_test,Y_test)
print accuracy_score(Y_pred_neural_test,Y_test)
# Out:
# [[154   5   4   1]
#  [  2 249   3   7]
#  [  2   2 185   1]
#  [  4   1   0 130]]
# 0.9573333333333334

# %%
pred_test_neural = clf_neural.predict(test_mapped)
pred_df = pd.DataFrame(pred_test_neural,columns=['SECTION'])
pred_df.to_csv(data_path+'/submission_nl12.csv',index=False)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model_rf = RandomForestClassifier(n_estimators=100)

# %%
model_rf.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
Y_pred_rf_test = model_rf.predict(X_test) #0.956
print confusion_matrix(Y_test,Y_pred_rf_test)
print accuracy_score(Y_test,Y_pred_rf_test)
# Out:
# [[154   2   4   2]
#  [  2 250   5   0]
#  [  4   1 186   1]
#  [  2   9   3 125]]
# 0.9533333333333334

# %%
Y_pred_rf_train = model_rf.predict(X_train)
print confusion_matrix(Y_train,Y_pred_rf_train)
print accuracy_score(Y_train,Y_pred_rf_train)
# Out:
# [[1499    0    0    0]
#  [   0 2447    0    0]
#  [   0    0 1714    0]
#  [   0    0    0 1089]]
# 1.0

# %%
processed_data_new = pd.read_csv('D:/Hands on ML/MachineHack News Category/art_clss_backup_art_clss_processed_data5.csv')

# %%
processed_data_new['STORY_LEM2_noverbpron'] = processed_data_new['STORY_LEM2_noverbpron'].apply(lambda x: " ".join(x for x in x.split() if len(x) > 2))

# %%
global noun_corpus_dict
noun_corpus_dict = {
    'noun_corpus_0':[],
    'noun_corpus_1':[],
    'noun_corpus_2':[],
    'noun_corpus_3':[]        
}
def specific_pos_corpus(x, flag,sec):
#     try:
    global noun_corpus_dict
    corpus = []
    current = noun_corpus_dict['noun_corpus_'+sec]
    wiki = TextBlob(x)
    for tup in wiki.tags:
        ppo = list(tup)[1]
        if ppo in pos_family[flag]:
            corpus = np.append(corpus,list(tup)[0])
    current.extend(corpus)
    noun_corpus_dict['noun_corpus_'+sec] = list(current)
#     except:
#         pass

# %%
processed_data_new.loc[processed_data_new['SECTION']==0]['STORY_LEM2_noverbpron'].apply(lambda x: specific_pos_corpus(x, 'noun','0'))
processed_data_new.loc[processed_data_new['SECTION']==1]['STORY_LEM2_noverbpron'].apply(lambda x: specific_pos_corpus(x, 'noun','1'))
processed_data_new.loc[processed_data_new['SECTION']==2]['STORY_LEM2_noverbpron'].apply(lambda x: specific_pos_corpus(x, 'noun','2'))
processed_data_new.loc[processed_data_new['SECTION']==3]['STORY_LEM2_noverbpron'].apply(lambda x: specific_pos_corpus(x, 'noun','3'))
# Out:
# 0       None
# 2       None
# 4       None
# 6       None
# 7       None
# 11      None
# 14      None
# 17      None
# 22      None
# 35      None
# 36      None
# 39      None
# 42      None
# 48      None
# 50      None
# 53      None
# 54      None
# 62      None
# 64      None
# 65      None
# 78      None
# 106     None
# 109     None
# 118     None
# 122     None
# 123     None
# 131     None
# 137     None
# 142     None
# 144     None
#         ...
# 7331    None
# 7332    None
# 7336    None
# 7339    None
# 7342    None
# 7346    None
# 7348    None
# 7350    None
# 7356    None
# 7357    None
# 7358    None
# 7364    None
# 7375    None
# 7381    None
# 7396    None
# 7398    None
# 7402    None
# 7405    None
# 7412    None
# 7437    None
# 7440    None
# 7442    None
# 7448    None
# 7452    None
# 7464    None
# 7473    None
# 7476    None
# 7480    None
# 7487    None
# 7489    None
# Name: STORY_LEM2_noverbpron, Length: 1229, dtype: object

# %%
noun_corpus_dict
# Out:
# {'noun_corpus_0': [u'opposition',
#   u'alliance',
#   u'jharkhand',
#   u'mukti',
#   u'jmm',
#   u'jharkhand',
#   u'vikas',
#   u'morcha',
#   u'prajatantrik',
#   u'story',
#   u'wire',
#   u'agency',
#   u'modification',
#   u'text',
#   u'headline',
#   u'statement',
#   u'air',
#   u'strike',
#   u'janata',
#   u'party',
#   u'bjp',
#   u'bag',
#   u'seat',
#   u'attack',
#   u'twist',
#   u'intent',
#   u'india',
#   u'air',
#   u'strike',
#   u'terrorist',
#   u'training',
#   u'camp',
#   u'jem',
#   u'statement',
#   u'context',
#   u'situation',
#   u'bjp',
#   u'month',
#   u'time',
#   u'bjp',
#   u'seat',
#   u'leadership',
#   u'modi',
#   u'yeddyurappa',
#   u'twitter',
#   u'control',
#   u'damage',
#   u'statement',
#   u'day',
#   u'game',
#   u'nation',
#   u'tension',
#   u'situation',
#   u'day',
#   u'age',
#   u'note',
#   u'india',
#   u'pakistan',
#   u'pti',
#   u'party',
#   u'country',
#   u'twitter',
#   u'hashtag',
#   u'election',
#   u'agriculture',
#   u'form',
#   u'part',
#   u'poll',
#   u'bjp',
#   u'banking',
#   u'scheme',
#   u'msp',
#   u'promise',
#   u'india',
#   u'vote',
#   u'party',
#   u'election',
#   u'april',
#   u'focus',
#   u'india',
#   u'election',
#   u'boil',
#   u'constituency',
#   u'seat',
#   u'number',
#   u'census',
#   u'classification',
#   u'constituency',
#   u'area',
#   u'importance',
#   u'fact',
#   u'bharatiya',
#   u'janata',
#   u'party',
#   u'seat',
#   u'election',
#   u'bjp',
#   u'caution',
#   u'fiasco',
#   u'campaign',
#   u'loss',
#   u'alliance',
#   u'power',
#   u'election',
#   u'congress',
#   u'opposition',
#   u'party',
#   u'bidding',
#   u'form',
#   u'alliance',
#   u'state',
#   u'stake',
#   u'agriculture',
#   u'form',
#   u'part',
#   u'election',
#   u'phase',
#   u'year',
#   u'india',
#   u'minister',
#   u'power',
#   u'drought',
#   u'year',
#   u'june',
#   u'way',
#   u'year',
#   u'monsoon',
#   u'record',
#   u'harvest',
#   u'grain',
#   u'horticulture',
#   u'crop',
#   u'plunge',
#   u'crop',
#   u'price',
#   u'government',
#   u'target',
#   u'income',
#   u'year',
#   u'reality',
#   u'farm',
#   u'revenue',
#   u'fall',
#   u'crop',
#   u'price',
#   u'food',
#   u'price',
#   u'year',
#   u'year',
#   u'month',
#   u'december',
#   u'yeddyurappa',
#   u'iaf',
#   u'air',
#   u'strike',
#   u'bag',
#   u'seat',
#   u'karnataka',
#   u'yeddyurappa',
#   u'remark',
#   u'pakistan',
#   u'play',
#   u'gallery',
#   u'victim',
#   u'poll',
#   u'reason',
#   u'action',
#   u'bengaluru',
#   u'bjp',
#   u'leader',
#   u'karnataka',
#   u'chief',
#   u'minister',
#   u'yeddyurappa',
#   u'headline',
#   u'comment',
#   u'air',
#   u'strike',
#   u'india',
#   u'terror',
#   u'camp',
#   u'border',
#   u'lok',
#   u'election',
#   u'news',
#   u'channel',
#   u'platform',
#   u'half',
#   u'dozen',
#   u'modi',
#   u'cutout',
#   u'giant',
#   u'screen',
#   u'party',
#   u'flag',
#   u'ground',
#   u'people',
#   u'city',
#   u'afternoon',
#   u'hour',
#   u'modi',
#   u'people',
#   u'saffron',
#   u'cap',
#   u'neck',
#   u'band',
#   u'chowkidar',
#   u'rally',
#   u'ground',
#   u'minister',
#   u'people',
#   u'police',
#   u'estimate',
#   u'ground',
#   u'part',
#   u'campaign',
#   u'bjp',
#   u'vote',
#   u'base',
#   u'vote',
#   u'phase',
#   u'election',
#   u'bjp',
#   u'seat',
#   u'odisha',
#   u'sabha',
#   u'poll',
#   u'party',
#   u'hope',
#   u'election',
#   u'change',
#   u'fortune',
#   u'state',
#   u'biju',
#   u'janata',
#   u'dal',
#   u'bjd',
#   u'minister',
#   u'naveen',
#   u'patnaik',
#   u'time',
#   u'conference',
#   u'congress',
#   u'alliance',
#   u'fray',
#   u'bjp',
#   u'ladakh',
#   u'jammu',
#   u'constituency',
#   u'region',
#   u'lok',
#   u'sabha',
#   u'election',
#   u'vote',
#   u'share',
#   u'valley',
#   u'eye',
#   u'vote',
#   u'poll',
#   u'union',
#   u'home',
#   u'ministry',
#   u'poll',
#   u'state',
#   u'election',
#   u'commission',
#   u'matter',
#   u'jammu',
#   u'kashmir',
#   u'government',
#   u'pdp',
#   u'bjp',
#   u'coalition',
#   u'june',
#   u'state',
#   u'governor',
#   u'rule',
#   u'december',
#   u'president',
#   u'rule',
#   u'state',
#   u'till',
#   u'june',
#   u'state',
#   u'election',
#   u'matter',
#   u'people',
#   u'poll',
#   u'turnout',
#   u'election',
#   u'level',
#   u'implication',
#   u'people',
#   u'government',
#   u'inspires',
#   u'confidence',
#   u'people',
#   u'climate',
#   u'state',
#   u'voter',
#   u'risk',
#   u'stone',
#   u'vote',
#   u'voter',
#   u'impact',
#   u'chance',
#   u'party',
#   u'term',
#   u'office',
#   u'something',
#   u'fact',
#   u'cluster',
#   u'station',
#   u'name',
#   u'security',
#   u'station',
#   u'distance',
#   u'village',
#   u'police',
#   u'personnel',
#   u'kilometre',
#   u'station',
#   u'voter',
#   u'jammu',
#   u'motivation',
#   u'vote',
#   u'something',
#   u'vote',
#   u'state',
#   u'poll',
#   u'bihar',
#   u'phase',
#   u'poll',
#   u'state',
#   u'assembly',
#   u'election',
#   u'election',
#   u'commission',
#   u'decision',
#   u'poll',
#   u'phase',
#   u'state',
#   u'lok',
#   u'election',
#   u'opposition',
#   u'party',
#   u'trinamool',
#   u'congress',
#   u'tmc',
#   u'concern',
#   u'schedule',
#   u'state',
#   u'ground',
#   u'election',
#   u'thanks',
#   u'move',
#   u'release',
#   u'advance',
#   u'crore',
#   u'crore',
#   u'assistance',
#   u'measure',
#   u'enhance',
#   u'preparedness',
#   u'response',
#   u'cyclone',
#   u'fani',
#   u'pradhan',
#   u'state',
#   u'president',
#   u'party',
#   u'candidate',
#   u'medinipur',
#   u'constituency',
#   u'dilip',
#   u'ghosh',
#   u'photo',
#   u'amit',
#   u'datta',
#   u'mint',
#   u'point',
#   u'programme',
#   u'bjp',
#   u'democracy',
#   u'democracy',
#   u'state',
#   u'government',
#   u'party',
#   u'distract',
#   u'people',
#   u'bjp',
#   u'shiv',
#   u'sena',
#   u'battle',
#   u'perception',
#   u'alliance',
#   u'convenience',
#   u'year',
#   u'round',
#   u'sena',
#   u'union',
#   u'government',
#   u'alliance',
#   u'convenience',
#   u'politics',
#   u'game',
#   u'compulsion',
#   u'limitation',
#   u'contradiction',
#   u'alliance',
#   u'convenience',
#   u'party',
#   u'criticism',
#   u'leadership',
#   u'thing',
#   u'judice',
#   u'court',
#   u'comment',
#   u'issue',
#   u'court',
#   u'effort',
#   u'court',
#   u'dispute',
#   u'union',
#   u'government',
#   u'strike',
#   u'pakistan',
#   u'balakot',
#   u'kind',
#   u'impact',
#   u'election',
#   u'opinion',
#   u'politicization',
#   u'issue',
#   u'security',
#   u'country',
#   u'opposition',
#   u'party',
#   u'act',
#   u'credit',
#   u'interest',
#   u'security',
#   u'everyone',
#   u'rise',
#   u'politics',
#   u'reason',
#   u'debate',
#   u'sharad',
#   u'giant',
#   u'time',
#   u'election',
#   u'time',
#   u'contest',
#   u'lok',
#   u'sabha',
#   u'poll',
#   u'party',
#   u'boycott',
#   u'election',
#   u'seat',
#   u'vacancy',
#   u'tuesday',
#   u'way',
#   u'win',
#   u'trs',
#   u'seat',
#   u'majilis',
#   u'muslimeen',
#   u'trs',
#   u'leader',
#   u'mlas',
#   u'party',
#   u'day',
#   u'congress',
#   u'mlas',
#   u'confirm',
#   u'congress',
#   u'congress',
#   u'committee',
#   u'tpcc',
#   u'mlc',
#   u'seat',
#   u'violation',
#   u'constitution',
#   u'tpcc',
#   u'president',
#   u'kumar',
#   u'march',
#   u'development',
#   u'congress',
#   u'foot',
#   u'performance',
#   u'state',
#   u'assembly',
#   u'election',
#   u'seat',
#   u'alliance',
#   u'telugu',
#   u'desam',
#   u'party',
#   u'party',
#   u'india',
#   u'telangana',
#   u'jana',
#   u'samithi',
#   u'seat',
#   u'tdp',
#   u'demand',
#   u'statehood',
#   u'part',
#   u'party',
#   u'campaign',
#   u'ground',
#   u'campaign',
#   u'issue',
#   u'survey',
#   u'show',
#   u'people',
#   u'leader',
#   u'statehood',
#   u'delhi',
#   u'people',
#   u'kejriwal',
#   u'minister',
#   u'narendra',
#   u'modi',
#   u'bihar',
#   u'minister',
#   u'kumar',
#   u'patna',
#   u'photo',
#   u'pti',
#   u'bihar',
#   u'bjp',
#   u'nda',
#   u'plan',
#   u'power',
#   u'election',
#   u'state',
#   u'lok',
#   u'sabha',
#   u'seat',
#   u'minister',
#   u'narendra',
#   u'modi',
#   u'alliance',
#   u'government',
#   u'secure',
#   u'life',
#   u'section',
#   u'country',
#   u'act',
#   u'terrorism',
#   u'fate',
#   u'candidate',
#   u'union',
#   u'minister',
#   u'subhash',
#   u'bhamre',
#   u'babul',
#   u'supriyo',
#   u'bjp',
#   u'union',
#   u'minister',
#   u'salman',
#   u'chowdhury',
#   u'congress',
#   u'voter',
#   u'phase',
#   u'fray',
#   u'kanhaiya',
#   u'kumar',
#   u'cpi',
#   u'panda',
#   u'bjp',
#   u'matondkar',
#   u'congress',
#   u'yadav',
#   u'samajwadi',
#   u'party',
#   u'satabdi',
#   u'roy',
#   u'tmc',
#   u'milind',
#   u'congress',
#   u'election',
#   u'commission',
#   u'station',
#   u'security',
#   u'arrangement',
#   u'election',
#   u'end',
#   u'phase',
#   u'opposition',
#   u'congress',
#   u'task',
#   u'base',
#   u'mumbai',
#   u'ncp',
#   u'district',
#   u'maharashtra',
#   u'bjp',
#   u'shiv',
#   u'seat',
#   u'union',
#   u'minister',
#   u'subhash',
#   u'leader',
#   u'milind',
#   u'deora',
#   u'matondkar',
#   u'fray',
#   u'phase',
#   u'rajasthan',
#   u'minister',
#   u'ashok',
#   u'gehlot',
#   u'son',
#   u'member',
#   u'jaipur',
#   u'family',
#   u'union',
#   u'minister',
#   u'fate',
#   u'monday',
#   u'seat',
#   u'congress',
#   u'state',
#   u'gehlot',
#   u'campaigning',
#   u'son',
#   u'vaibhav',
#   u'union',
#   u'minister',
#   u'state',
#   u'gajendra',
#   u'singh',
#   u'shekhawat',
#   u'rajasthan',
#   u'bjp',
#   u'seat',
#   u'congress',
#   u'comeback',
#   u'government',
#   u'state',
#   u'majority',
#   u'year',
#   u'poll',
#   u'congress',
#   u'hariprasad',
#   u'rajya',
#   u'member',
#   u'candidate',
#   u'seat',
#   u'anticipation',
#   u'tejaswini',
#   u'candidature',
#   u'congress',
#   u'change',
#   u'candidature',
#   u'chance',
#   u'win',
#   u'constituency',
#   u'party',
#   u'advantage',
#   u'work',
#   u'ground',
#   u'couple',
#   u'day',
#   u'nomination',
#   u'congress',
#   u'push',
#   u'krishna',
#   u'byre',
#   u'gowda',
#   u'bjp',
#   u'sadananda',
#   u'gowda',
#   u'ground',
#   u'time',
#   u'people',
#   u'seat',
#   u'congress',
#   u'rahul',
#   u'state',
#   u'today',
#   u'ease',
#   u'business',
#   u'electricity',
#   u'authority',
#   u'state',
#   u'number',
#   u'regard',
#   u'electricity',
#   u'situation',
#   u'meeting',
#   u'karimnagar',
#   u'district',
#   u'sunday',
#   u'minister',
#   u'president',
#   u'statement',
#   u'amount',
#   u'money',
#   u'centre',
#   u'telangana',
#   u'sentiment',
#   u'hindu',
#   u'community',
#   u'happens',
#   u'contest',
#   u'seat',
#   u'face',
#   u'problem',
#   u'bsp',
#   u'chief',
#   u'see',
#   u'damage',
#   u'alliance',
#   u'uttar',
#   u'pradesh',
#   u'state',
#   u'assam',
#   u'bihar',
#   u'andhra',
#   u'pradesh',
#   u'kerala',
#   u'chhattisgarh',
#   u'rajasthan',
#   u'percentage',
#   u'voter',
#   u'average',
#   u'cent',
#   u'increase',
#   u'voter',
#   u'state',
#   u'maharashtra',
#   u'population',
#   u'increase',
#   u'voter',
#   u'cent',
#   u'improvement',
#   u'woman',
#   u'voter',
#   u'turnout',
#   u'jan',
#   u'dhan',
#   u'mudra',
#   u'lead',
#   u'woman',
#   u'empowerment',
#   u'address',
#   u'minister',
#   u'india',
#   u'earth',
#   u'orbit',
#   u'space',
#   u'power',
#   u'mission',
#   u'minute',
#   u'mission',
#   u'shakti',
#   u'yechury',
#   u'letter',
#   u'election',
#   u'commissioner',
#   u'speech',
#   u'election',
#   u'commission',
#   u'list',
#   u'remark',
#   u'incursion',
#   u'argument',
#   u'need',
#   u'attention',
#   u'yeddyurappa',
#   u'statement',
#   u'pakistan',
#   u'play',
#   u'gallery',
#   u'victim',
#   u'election',
#   u'reason',
#   u'action',
#   u'allegation',
#   u'ground',
#   u'bjp',
#   u'medium',
#   u'question',
#   u'comment',
#   u'congress',
#   u'assault',
#   u'yeddyurappa',
#   u'wednesday',
#   u'report',
#   u'speech',
#   u'state',
#   u'government',
#   u'medium',
#   u'issue',
#   u'content',
#   u'vote',
#   u'describe',
#   u'missile',
#   u'launch',
#   u'government',
#   u'scientist',
#   u'view',
#   u'commission',
#   u'speech',
#   u'violate',
#   u'model',
#   u'code',
#   u'letter',
#   u'code',
#   u'india',
#   u'shot',
#   u'satellite',
#   u'space',
#   u'wednesday',
#   u'satellite',
#   u'missile',
#   u'demonstrate',
#   u'capability',
#   u'minister',
#   u'narendra',
#   u'country',
#   u'weapon',
#   u'jmm',
#   u'president',
#   u'soren',
#   u'jharkhand',
#   u'babulal',
#   u'marandi',
#   u'soren',
#   u'tribals',
#   u'election',
#   u'rally',
#   u'district',
#   u'news',
#   u'agency',
#   u'pti',
#   u'congress',
#   u'president',
#   u'gandhi',
#   u'state',
#   u'opposition',
#   u'alliance',
#   u'party',
#   u'voice',
#   u'people',
#   u'alliance',
#   u'part',
#   u'lok',
#   u'sabha',
#   u'constituency',
#   u'place',
#   u'election',
#   u'campaign',
#   u'bjp',
#   u'strategy',
#   u'state',
#   u'appoint',
#   u'non',
#   u'leader',
#   u'chief',
#   u'minister',
#   u'population',
#   u'state',
#   u'minister',
#   u'jharkhand',
#   u'leader',
#   u'time',
#   u'bjp',
#   u'non',
#   u'person',
#   u'raghubar',
#   u'chief',
#   u'candidate',
#   u'bjp',
#   u'power',
#   u'jharkhand',
#   u'election',
#   u'lok',
#   u'sabha',
#   u'poll',
#   u'time',
#   u'party',
#   u'test',
#   u'state',
#   u'government',
#   u'time',
#   u'leadership',
#   u'minister',
#   u'narendra',
#   u'modi',
#   u'party',
#   u'state',
#   u'bjp',
#   u'leader',
#   u'ranchi',
#   u'video',
#   u'deora',
#   u'union',
#   u'minister',
#   u'twitter',
#   u'page',
#   u'ambani',
#   u'milind',
#   u'man',
#   u'mumbai',
#   u'mumbai',
#   u'connection',
#   u'support',
#   u'ambani',
#   u'businessmen',
#   u'trader',
#   u'milind',
#   u'man',
#   u'year',
#   u'milind',
#   u'depth',
#   u'eco',
#   u'system',
#   u'constituency',
#   u'ambani',
#   u'video',
#   u'congress',
#   u'tumkur',
#   u'muddahanumegowda',
#   u'decision',
#   u'tension',
#   u'congress',
#   u'janata',
#   u'dal',
#   u'party',
#   u'friday',
#   u'member',
#   u'parliament',
#   u'nomination',
#   u'tumakuru',
#   u'seat',
#   u'contest',
#   u'decision',
#   u'party',
#   u'coalition',
#   u'agreement',
#   u'random',
#   u'chit',
#   u'number',
#   u'vote',
#   u'machine',
#   u'vehicle',
#   u'voting',
#   u'machine',
#   u'gps',
#   u'device',
#   u'monitor',
#   u'movement',
#   u'parliament',
#   u'lawmaker',
#   u'charge',
#   u'case',
#   u'murder',
#   u'rape',
#   u'time',
#   u'cloud',
#   u'issue',
#   u'newspaper',
#   u'advertisement',
#   u'charge',
#   u'face',
#   u'constituency',
#   u'association',
#   u'reform',
#   u'adr',
#   u'charity',
#   u'charge',
#   u'chance',
#   u'election',
#   u'voter',
#   u'influence',
#   u'candidate',
#   u'income',
#   u'tax',
#   u'return',
#   u'year',
#   u'information',
#   u'vote',
#   u'detail',
#   u'asset',
#   u'liability',
#   u'name',
#   u'internet',
#   u'monitor',
#   u'station',
#   u'hall',
#   u'eye',
#   u'time',
#   u'thirty',
#   ...],
#  'noun_corpus_1': [u'question',
#   u'click',
#   u'answer',
#   u'user',
#   u'answer',
#   u'voice',
#   u'command',
#   u'question',
#   u'click',
#   u'ask',
#   u'question',
#   u'question',
#   u'help',
#   u'question',
#   u'question',
#   u'question',
#   u'question',
#   u'click',
#   u'click',
#   u'bell',
#   u'question',
#   u'tech',
#   u'giant',
#   u'huawei',
#   u'plan',
#   u'generation',
#   u'smartphone',
#   u'technology',
#   u'component',
#   u'effort',
#   u'industry',
#   u'leader',
#   u'announcement',
#   u'huawei',
#   u'technology',
#   u'world',
#   u'maker',
#   u'network',
#   u'phone',
#   u'company',
#   u'combat',
#   u'company',
#   u'security',
#   u'risk',
#   u'development',
#   u'process',
#   u'flaw',
#   u'market',
#   u'vice',
#   u'president',
#   u'device',
#   u'research',
#   u'consultancy',
#   u'note',
#   u'incident',
#   u'build',
#   u'reputation',
#   u'product',
#   u'note',
#   u'episode',
#   u'recall',
#   u'cost',
#   u'company',
#   u'dollar',
#   u'reputation',
#   u'apple',
#   u'inc',
#   u'premium',
#   u'device',
#   u'address',
#   u'issue',
#   u'race',
#   u'gadget',
#   u'huawei',
#   u'technology',
#   u'xiaomi',
#   u'corp',
#   u'samsung',
#   u'spokeswoman',
#   u'comment',
#   u'story',
#   u'share',
#   u'company',
#   u'hasn',
#   u'set',
#   u'date',
#   u'launch',
#   u'seoul',
#   u'note',
#   u'world',
#   u'producer',
#   u'smartphones',
#   u'memory',
#   u'chip',
#   u'lead',
#   u'mobile',
#   u'start',
#   u'market',
#   u'version',
#   u'flagship',
#   u'galaxy',
#   u'phone',
#   u'ambition',
#   u'product',
#   u'korea',
#   u'giant',
#   u'gadget',
#   u'edge',
#   u'innovation',
#   u'presence',
#   u'market',
#   u'growth',
#   u'smartphones',
#   u'entrepreneur',
#   u'xiaomi',
#   u'store',
#   u'infrastructure',
#   u'estate',
#   u'xiaomi',
#   u'company',
#   u'detail',
#   u'bell',
#   u'bezel',
#   u'lag',
#   u'bloatware',
#   u'price',
#   u'tag',
#   u'random',
#   u'music',
#   u'phone',
#   u'smartphone',
#   u'triple',
#   u'camera',
#   u'setup',
#   u'front',
#   u'camera',
#   u'mechanism',
#   u'copper',
#   u'heat',
#   u'sketch',
#   u'sim',
#   u'card',
#   u'slot',
#   u'side',
#   u'design',
#   u'smartphone',
#   u'line',
#   u'case',
#   u'magazine',
#   u'hand',
#   u'production',
#   u'prototype',
#   u'camera',
#   u'sample',
#   u'device',
#   u'prix',
#   u'baku',
#   u'feature',
#   u'help',
#   u'turn',
#   u'experience',
#   u'battery',
#   u'feature',
#   u'toggle',
#   u'asus',
#   u'rog',
#   u'phone',
#   u'razer',
#   u'phone',
#   u'tiktok',
#   u'criticism',
#   u'quarter',
#   u'circulation',
#   u'content',
#   u'user',
#   u'tiktok',
#   u'app',
#   u'smartphone',
#   u'share',
#   u'seeker',
#   u'delhi',
#   u'crore',
#   u'people',
#   u'option',
#   u'share',
#   u'others',
#   u'access',
#   u'google',
#   u'play',
#   u'store',
#   u'apple',
#   u'store',
#   u'criticism',
#   u'quarter',
#   u'circulation',
#   u'content',
#   u'google',
#   u'apple',
#   u'download',
#   u'video',
#   u'app',
#   u'request',
#   u'government',
#   u'opera',
#   u'house',
#   u'show',
#   u'apple',
#   u'ipad',
#   u'type',
#   u'audience',
#   u'artist',
#   u'apple',
#   u'fact',
#   u'sale',
#   u'measure',
#   u'ship',
#   u'apple',
#   u'end',
#   u'ipad',
#   u'artist',
#   u'photographer',
#   u'creator',
#   u'people',
#   u'month',
#   u'change',
#   u'apple',
#   u'price',
#   u'iphones',
#   u'year',
#   u'investor',
#   u'iphone',
#   u'sale',
#   u'price',
#   u'increase',
#   u'revenue',
#   u'time',
#   u'start',
#   u'facebook',
#   u'creator',
#   u'money',
#   u'video',
#   u'break',
#   u'photo',
#   u'facebook',
#   u'watch',
#   u'video',
#   u'encourage',
#   u'people',
#   u'share',
#   u'facebookfacebook',
#   u'watchfacebook',
#   u'watch',
#   u'video',
#   u'serviceyoutubefidji',
#   u'simoentertainmentsports',
#   u'contenttechnology',
#   u'startup',
#   u'zeta',
#   u'bhavin',
#   u'turakhia',
#   u'ramki',
#   u'gaddipati',
#   u'aim',
#   u'digitise',
#   u'employee',
#   u'benefit',
#   u'fintech',
#   u'startup',
#   u'zeta',
#   u'bhavin',
#   u'turakhia',
#   u'ramki',
#   u'gaddipati',
#   u'aim',
#   u'digitise',
#   u'employee',
#   u'benefit',
#   u'solution',
#   u'reward',
#   u'recognition',
#   u'solution',
#   u'cloud',
#   u'suite',
#   u'zeta',
#   u'tax',
#   u'benefit',
#   u'package',
#   u'payment',
#   u'solution',
#   u'company',
#   u'footprint',
#   u'partnership',
#   u'alliance',
#   u'note',
#   u'wresearch',
#   u'note',
#   u'company',
#   u'printing',
#   u'market',
#   u'space',
#   u'technology',
#   u'brahma',
#   u'robotics',
#   u'research',
#   u'bench',
#   u'hand',
#   u'institute',
#   u'microsoft',
#   u'hololens',
#   u'network',
#   u'tool',
#   u'link',
#   u'protein',
#   u'gene',
#   u'disorder',
#   u'cancer',
#   u'example',
#   u'technology',
#   u'reality',
#   u'reality',
#   u'world',
#   u'user',
#   u'business',
#   u'world',
#   u'mixed',
#   u'reality',
#   u'reality',
#   u'concept',
#   u'world',
#   u'computer',
#   u'world',
#   u'element',
#   u'world',
#   u'atop',
#   u'layer',
#   u'information',
#   u'mix',
#   u'reality',
#   u'bid',
#   u'capture',
#   u'world',
#   u'reality',
#   u'gain',
#   u'traction',
#   u'reality',
#   u'content',
#   u'investor',
#   u'reality',
#   u'become',
#   u'platform',
#   u'magic',
#   u'company',
#   u'investment',
#   u'google',
#   u'alibaba',
#   u'group',
#   u'investment',
#   u'management',
#   u'month',
#   u'reality',
#   u'headset',
#   u'maker',
#   u'creator',
#   u'edition',
#   u'player',
#   u'market',
#   u'intel',
#   u'epson',
#   u'corp',
#   u'microsoft',
#   u'corp',
#   u'accenture',
#   u'plc',
#   u'google',
#   u'inc',
#   u'sony',
#   u'corp',
#   u'samsung',
#   u'electronics',
#   u'facebook',
#   u'inc',
#   u'htc',
#   u'corp',
#   u'start',
#   u'ups',
#   u'technology',
#   u'research',
#   u'firm',
#   u'gartner',
#   u'solution',
#   u'enterprise',
#   u'business',
#   u'market',
#   u'size',
#   u'research',
#   u'firm',
#   u'belief',
#   u'growth',
#   u'product',
#   u'aerospace',
#   u'defence',
#   u'sector',
#   u'product',
#   u'technology',
#   u'school',
#   u'image',
#   u'experience',
#   u'report',
#   u'mint',
#   u'wire',
#   u'technologyfuture',
#   u'thing',
#   u'reality',
#   u'iphone',
#   u'ipad',
#   u'app',
#   u'tap',
#   u'tap',
#   u'software',
#   u'version',
#   u'update',
#   u'iphone',
#   u'ipad',
#   u'power',
#   u'source',
#   u'mac',
#   u'app',
#   u'store',
#   u'app',
#   u'click',
#   u'tab',
#   u'click',
#   u'macos',
#   u'version',
#   u'mac',
#   u'system',
#   u'option',
#   u'download',
#   u'download',
#   u'power',
#   u'cable',
#   u'restart',
#   u'computer',
#   u'preview',
#   u'insider',
#   u'phone',
#   u'notification',
#   u'time',
#   u'customise',
#   u'notification',
#   u'notification',
#   u'boost',
#   u'focus',
#   u'productivity',
#   u'phone',
#   u'notification',
#   u'control',
#   u'manage',
#   u'notification',
#   u'notification',
#   u'device',
#   u'company',
#   u'post',
#   u'device',
#   u'shareholder',
#   u'reverse',
#   u'sale',
#   u'apple',
#   u'cut',
#   u'sale',
#   u'outlook',
#   u'time',
#   u'decade',
#   u'demand',
#   u'cameraiphone',
#   u'tim',
#   u'china',
#   u'baniphone',
#   u'china',
#   u'banapple',
#   u'loss',
#   u'caller',
#   u'mute',
#   u'reconnect',
#   u'lecture',
#   u'mode',
#   u'person',
#   u'speak',
#   u'others',
#   u'tech',
#   u'giant',
#   u'september',
#   u'launch',
#   u'iphone',
#   u'model',
#   u'award',
#   u'scientist',
#   u'researcher',
#   u'engineer',
#   u'scientist',
#   u'infosys',
#   u'science',
#   u'foundation',
#   u'rank',
#   u'award',
#   u'india',
#   u'recognise',
#   u'research',
#   u'eminent',
#   u'professor',
#   u'infosys',
#   u'category',
#   u'science',
#   u'research',
#   u'award',
#   u'pure',
#   u'gold',
#   u'citation',
#   u'purse',
#   u'rupee',
#   u'intelligenceinfosys',
#   u'science',
#   u'foundationinternet',
#   u'thingsiotmachine',
#   u'learningml',
#   u'tech',
#   u'giant',
#   u'tez',
#   u'part',
#   u'effort',
#   u'payment',
#   u'app',
#   u'online',
#   u'merchant',
#   u'country',
#   u'everyone',
#   u'world',
#   u'partnership',
#   u'railtel',
#   u'example',
#   u'people',
#   u'railway',
#   u'station',
#   u'manager',
#   u'payment',
#   u'caesar',
#   u'sengupta',
#   u'google',
#   u'google',
#   u'station',
#   u'service',
#   u'location',
#   u'partnership',
#   u'entity',
#   u'google',
#   u'station',
#   u'country',
#   u'indonesia',
#   u'nigeria',
#   u'apsfnl',
#   u'service',
#   u'end',
#   u'year',
#   u'city',
#   u'health',
#   u'care',
#   u'place',
#   u'executive',
#   u'label',
#   u'people',
#   u'phone',
#   u'icon',
#   u'phone',
#   u'screen',
#   u'speed',
#   u'network',
#   u'indicator',
#   u'mean',
#   u'speed',
#   u'cost',
#   u'people',
#   u'access',
#   u'speed',
#   u'consumer',
#   u'data',
#   u'technology',
#   u'carrier',
#   u'announce',
#   u'pricing',
#   u'data',
#   u'plan',
#   u'phone',
#   u'case',
#   u'price',
#   u'samsung',
#   u'pricing',
#   u'galaxy',
#   u'device',
#   u'part',
#   u'compatibility',
#   u'depth',
#   u'camera',
#   u'samsung',
#   u'phone',
#   u'change',
#   u'price',
#   u'price',
#   u'start',
#   u'galaxy',
#   u'carolina',
#   u'milanesi',
#   u'analyst',
#   u'strategy',
#   u'price',
#   u'term',
#   u'iphone',
#   u'review',
#   u'consumer',
#   u'point',
#   u'people',
#   u'technology',
#   u'phone',
#   u'don',
#   u'smartphone',
#   u'maker',
#   u'partnership',
#   u'collaboration',
#   u'brand',
#   u'december',
#   u'partnership',
#   u'mclaren',
#   u'team',
#   u'formula',
#   u'history',
#   u'collaboration',
#   u'mclaren',
#   u'term',
#   u'technology',
#   u'partnership',
#   u'legacy',
#   u'brand',
#   u'speed',
#   u'innovation',
#   u'partnership',
#   u'ceo',
#   u'founder',
#   u'pete',
#   u'lau',
#   u'mclaren',
#   u'way',
#   u'dream',
#   u'create',
#   u'something',
#   u'nothing',
#   u'today',
#   u'innovation',
#   u'salute',
#   u'speed',
#   u'company',
#   u'iphone',
#   u'price',
#   u'dollar',
#   u'predecessor',
#   u'consumer',
#   u'country',
#   u'currency',
#   u'dollar',
#   u'phone',
#   u'pricier',
#   u'predecessor',
#   u'year',
#   u'apple',
#   u'consumer',
#   u'cost',
#   u'dollar',
#   u'tuesday',
#   u'cook',
#   u'apple',
#   u'price',
#   u'market',
#   u'year',
#   u'currency',
#   u'mean',
#   u'apple',
#   u'cost',
#   u'dollar',
#   u'end',
#   u'television',
#   u'premium',
#   u'brand',
#   u'value',
#   u'brand',
#   u'compromise',
#   u'don',
#   u'television',
#   u'bring',
#   u'picture',
#   u'quality',
#   u'technology',
#   u'zone',
#   u'philip',
#   u'micro',
#   u'technology',
#   u'dimming',
#   u'increase',
#   u'contrast',
#   u'predator',
#   u'screen',
#   u'time',
#   u'area',
#   u'screen',
#   u'resolution',
#   u'refresh',
#   u'rate',
#   u'support',
#   u'tobii',
#   u'eye',
#   u'technology',
#   u'gamers',
#   u'player',
#   u'action',
#   u'game',
#   u'cry',
#   u'eye',
#   u'head',
#   u'movement',
#   u'attack',
#   u'access',
#   u'network',
#   u'traffic',
#   u'analysis',
#   u'iit',
#   u'rogue',
#   u'router',
#   u'access',
#   u'point',
#   u'hacker',
#   u'choice',
#   u'viewer',
#   u'determine',
#   u'decision',
#   u'time',
#   u'report',
#   u'court',
#   u'notice',
#   u'rbi',
#   u'google',
#   u'india',
#   u'issue',
#   u'plea',
#   u'mishra',
#   u'gpay',
#   u'figure',
#   u'list',
#   u'payment',
#   u'system',
#   u'bank',
#   u'march',
#   u'investigation',
#   u'samsung',
#   u'layer',
#   u'film',
#   u'something',
#   u'hadn',
#   u'product',
#   u'people',
#   u'matter',
#   u'designer',
#   u'crease',
#   u'device',
#   u'see',
#   u'device',
#   u'improvement',
#   u'experience',
#   u'samsung',
#   u'statement',
#   u'feedback',
#   u'test',
#   u'delay',
#   u'release',
#   u'galaxy',
#   u'plan',
#   u'release',
#   u'date',
#   u'week',
#   u'production',
#   u'scale',
#   u'phone',
#   u'problem',
#   u'impact',
#   u'note',
#   u'samsung',
#   u'forecast',
#   u'unit',
#   u'year',
#   u'fraction',
#   u'smartphones',
#   u'company',
#   u'share',
#   u'seoul',
#   u'tuesday',
#   u'trading',
#   u'day',
#   u'announcement',
#   u'question',
#   u'process',
#   u'year',
#   u'samsung',
#   u'galaxy',
#   u'launch',
#   u'year',
#   u'decision',
#   u'delay',
#   u'company',
#   u'note',
#   u'debacle',
#   u'anthea',
#   u'analyst',
#   u'bloomberg',
#   u'intelligence',
#   u'email',
#   u'tuesday',
#   u'google',
#   u'custom',
#   u'server',
#   u'delhi',
#   u'rise',
#   u'internet',
#   u'fraud',
#   u'data',
#   u'breach',
#   u'couple',
#   u'year',
#   u'nation',
#   u'state',
#   u'actor',
#   u'government',
#   u'data',
#   u'tech',
#   u'company',
#   u'place',
#   u'line',
#   u'measure',
#   u'stay',
#   u'hacker',
#   u'consumer',
#   u'data',
#   u'data',
#   u'centre',
#   u'facility',
#   u'scale',
#   u'attack',
#   u'priority',
#   u'giant',
#   u'google',
#   u'amazon',
#   u'facebook',
#   u'others',
#   u'shipping',
#   u'container',
#   u'size',
#   u'data',
#   u'centre',
#   u'scotland',
#   u'island',
#   u'help',
#   u'community',
#   u'internet',
#   u'secure',
#   u'way',
#   u'whatsapp',
#   u'beta',
#   u'emojis',
#   u'transgender',
#   u'flag',
#   u'flag',
#   u'pride',
#   u'flag',
#   u'emoji',
#   u'transgender',
#   u'symbol',
#   u'exchange',
#   u'exchange',
#   u'device',
#   u'claim',
#   u'company',
#   u'handset',
#   u'combination',
#   u'ram',
#   u'storage',
#   u'technology',
#   u'charge',
#   u'beneath',
#   u'glass',
#   u'phone',
#   u'design',
#   u'carbon',
#   u'feature',
#   u'customer',
#   u'mclaren',
#   u'mclaren',
#   u'carbon',
#   u'fiber',
#   u'claim',
#   u'car',
#   u'carbon',
#   u'fiber',
#   u'production',
#   u'customer',
#   u'book',
#   u'history',
#   u'company',
#   u'month',
#   u'google',
#   u'secure',
#   u'user',
#   u'technology',
#   u'google',
#   u'assistant',
#   u'guard',
#   u'alphabet',
#   u'inc',
#   u'google',
#   u'wednesday',
#   u'error',
#   u'secure',
#   u'home',
#   u'security',
#   u'system',
#   u'device',
#   u'smartphones',
#   u'camera',
#   u'effect',
#   u'example',
#   u'year',
#   u'iphone',
#   u'camera',
#   u'lens',
#   u'bokeh',
#   u'effect',
#   u'galaxy',
#   u'notch',
#   u'triple',
#   u'camera',
#   u'system',
#   u'phone',
#   u'camera',
#   u'feature',
#   u'brand',
#   u'angle',
#   u'shot',
#   u'landscape',
#   u'group',
#   u'dinner',
#   u'camera',
#   u'depth',
#   u'reality',
#   u'application',
#   u'use',
#   u'data',
#   u'world',
#   u'people',
#   u'company',
#   u'number',
#   u'camera',
#   u'year',
#   u'apple',
#   u'camera',
#   u'iphones',
#   u'person',
#   u'company',
#   u'plan',
#   u'condition',
#   u'anonymity',
#   u'apple',
#   u'comment',
#   u'galaxy',
#   u'phone',
#   u'work',
#   u'wireless',
#   u'network',
#   u'successor',
#   u'network',
#   u'network',
#   u'introduce',
#   u'internet',
#   u'speed',
#   u'device',
#   u'download',
#   u'quality',
#   u'contain',
#   u'excitement',
#   u'carrier',
#   u'network',
#   u'city',
#   u'half',
#   u'year',
#   u'verizon',
#   u'test',
#   u'smartphone',
#   ...],
#  'noun_corpus_2': [u'audience',
#   u'yeh',
#   u'hai',
#   u'pyaar',
#   u'tune',
#   u'kind',
#   u'people',
#   u'situation',
#   u'com',
#   u'arbaaz',
#   u'khan',
#   u'character',
#   u'year',
#   u'dabangg',
#   u'salman',
#   u'song',
#   u'indore',
#   u'arbaaz',
#   u'brother',
#   u'set',
#   u'colleague',
#   u'move',
#   u'mother',
#   u'house',
#   u'form',
#   u'relation',
#   u'time',
#   u'episode',
#   u'dare',
#   u'happiness',
#   u'mother',
#   u'offer',
#   u'explanation',
#   u'phil',
#   u'people',
#   u'pop',
#   u'culture',
#   u'reference',
#   u'reference',
#   u'girl',
#   u'mindy',
#   u'others',
#   u'varun',
#   u'dhawan',
#   u'bhatt',
#   u'sonakshi',
#   u'sinha',
#   u'aditya',
#   u'roy',
#   u'madhuri',
#   u'dixit',
#   u'sanjay',
#   u'dutt',
#   u'opening',
#   u'wednesday',
#   u'maker',
#   u'weekend',
#   u'competition',
#   u'film',
#   u'time',
#   u'box',
#   u'office',
#   u'start',
#   u'bang',
#   u'opener',
#   u'plexes',
#   u'cast',
#   u'hype',
#   u'screen',
#   u'count',
#   u'holiday',
#   u'total',
#   u'release',
#   u'year',
#   u'milan',
#   u'actor',
#   u'zoya',
#   u'factor',
#   u'kapoor',
#   u'dulquer',
#   u'salmaan',
#   u'sikandar',
#   u'bollywood',
#   u'debut',
#   u'film',
#   u'aurangzeb',
#   u'player',
#   u'laden',
#   u'others',
#   u'people',
#   u'performance',
#   u'feel',
#   u'reason',
#   u'project',
#   u'way',
#   u'don',
#   u'ten',
#   u'film',
#   u'avenger',
#   u'endgame',
#   u'infinity',
#   u'war',
#   u'avenger',
#   u'avenger',
#   u'age',
#   u'panther',
#   u'dollar',
#   u'slot',
#   u'movie',
#   u'time',
#   u'list',
#   u'rest',
#   u'film',
#   u'suit',
#   u'titanic',
#   u'television',
#   u'actor',
#   u'playing',
#   u'raghav',
#   u'hindi',
#   u'show',
#   u'jassi',
#   u'jaisi',
#   u'koi',
#   u'nahi',
#   u'monday',
#   u'connection',
#   u'rape',
#   u'case',
#   u'fir',
#   u'oshiwara',
#   u'police',
#   u'station',
#   u'mumbai',
#   u'section',
#   u'rape',
#   u'penal',
#   u'code',
#   u'guy',
#   u'marvel',
#   u'movie',
#   u'anything',
#   u'kind',
#   u'industry',
#   u'report',
#   u'rife',
#   u'closure',
#   u'character',
#   u'iron',
#   u'man',
#   u'captain',
#   u'phase',
#   u'mcu',
#   u'brie',
#   u'pressure',
#   u'pressure',
#   u'sort',
#   u'thing',
#   u'debut',
#   u'barroz',
#   u'film',
#   u'backdrop',
#   u'diner',
#   u'scene',
#   u'smash',
#   u'right',
#   u'scene',
#   u'lab',
#   u'gene',
#   u'scene',
#   u'man',
#   u'didn',
#   u'infinity',
#   u'war',
#   u'man',
#   u'pay',
#   u'endgame',
#   u'movie',
#   u'infinity',
#   u'war',
#   u'movie',
#   u'tone',
#   u'weird',
#   u'right',
#   u'movie',
#   u'everybody',
#   u'story',
#   u'tell',
#   u'movie',
#   u'anybody',
#   u'family',
#   u'war',
#   u'markus',
#   u'time',
#   u'scene',
#   u'movie',
#   u'snap',
#   u'pop',
#   u'clint',
#   u'farm',
#   u'watching',
#   u'indication',
#   u'wider',
#   u'effect',
#   u'panther',
#   u'captain',
#   u'try',
#   u'opportunity',
#   u'character',
#   u'film',
#   u'wasn',
#   u'lot',
#   u'time',
#   u'test',
#   u'panther',
#   u'cap',
#   u'wakanda',
#   u'audience',
#   u'test',
#   u'movie',
#   u'noise',
#   u'people',
#   u'story',
#   u'avenger',
#   u'loss',
#   u'conclusion',
#   u'blood',
#   u'marvel',
#   u'character',
#   u'movie',
#   u'couldn',
#   u'movie',
#   u'level',
#   u'architecture',
#   u'throw',
#   u'series',
#   u'device',
#   u'movie',
#   u'way',
#   u'time',
#   u'movie',
#   u'time',
#   u'time',
#   u'character',
#   u'end',
#   u'natasha',
#   u'way',
#   u'time',
#   u'idea',
#   u'time',
#   u'story',
#   u'line',
#   u'point',
#   u'time',
#   u'stone',
#   u'use',
#   u'time',
#   u'let',
#   u'week',
#   u'thing',
#   u'time',
#   u'movie',
#   u'markus',
#   u'time',
#   u'travel',
#   u'character',
#   u'wise',
#   u'people',
#   u'realm',
#   u'time',
#   u'thing',
#   u'mcu',
#   u'character',
#   u'film',
#   u'formulation',
#   u'time',
#   u'travel',
#   u'change',
#   u'don',
#   u'alter',
#   u'present',
#   u'bank',
#   u'executive',
#   u'show',
#   u'max',
#   u'john',
#   u'quinn',
#   u'actor',
#   u'gautham',
#   u'karthik',
#   u'twitter',
#   u'share',
#   u'upcoming',
#   u'film',
#   u'space',
#   u'str',
#   u'time',
#   u'super',
#   u'space',
#   u'super',
#   u'str',
#   u'bro',
#   u'tweet',
#   u'day',
#   u'day',
#   u'biggies',
#   u'film',
#   u'industry',
#   u'avengersendgame',
#   u'weekend',
#   u'twitter',
#   u'craze',
#   u'avengersendgame',
#   u'moviegoer',
#   u'wallet',
#   u'purse',
#   u'shell',
#   u'money',
#   u'ticket',
#   u'film',
#   u'worth',
#   u'film',
#   u'screen',
#   u'avengersendgame',
#   u'shatters',
#   u'screen',
#   u'count',
#   u'number',
#   u'day',
#   u'weekend',
#   u'avengersendgame',
#   u'hindi',
#   u'biggies',
#   u'ray',
#   u'ritwik',
#   u'ghatak',
#   u'filmmaker',
#   u'kolkata',
#   u'ftii',
#   u'pune',
#   u'vice',
#   u'ghatak',
#   u'brilliant',
#   u'film',
#   u'box',
#   u'office',
#   u'film',
#   u'producer',
#   u'kolkata',
#   u'fund',
#   u'film',
#   u'year',
#   u'inspire',
#   u'institute',
#   u'ghatak',
#   u'mentor',
#   u'wave',
#   u'film',
#   u'mani',
#   u'kaul',
#   u'kumar',
#   u'proponent',
#   u'parallel',
#   u'cinema',
#   u'ghatak',
#   u'fan',
#   u'kaul',
#   u'shahani',
#   u'tribute',
#   u'ritwik',
#   u'ghatak',
#   u'poona',
#   u'ray',
#   u'book',
#   u'film',
#   u'film',
#   u'ghatak',
#   u'trait',
#   u'gandhi',
#   u'marie',
#   u'seton',
#   u'admirer',
#   u'satyajit',
#   u'ray',
#   u'ffsi',
#   u'president',
#   u'life',
#   u'medium',
#   u'film',
#   u'society',
#   u'activist',
#   u'author',
#   u'india',
#   u'film',
#   u'society',
#   u'movement',
#   u'journey',
#   u'impact',
#   u'actor',
#   u'board',
#   u'medium',
#   u'space',
#   u'year',
#   u'actor',
#   u'join',
#   u'chase',
#   u'dillon',
#   u'aaron',
#   u'pierre',
#   u'project',
#   u'adaptation',
#   u'book',
#   u'name',
#   u'variety',
#   u'hollywood',
#   u'veteran',
#   u'robert',
#   u'jibe',
#   u'president',
#   u'trump',
#   u'time',
#   u'gangster',
#   u'actor',
#   u'comment',
#   u'appearance',
#   u'show',
#   u'stephen',
#   u'colbert',
#   u'episode',
#   u'mueller',
#   u'report',
#   u'evidence',
#   u'collusion',
#   u'trump',
#   u'campaign',
#   u'government',
#   u'election',
#   u'year',
#   u'music',
#   u'producer',
#   u'help',
#   u'injury',
#   u'confirm',
#   u'adam',
#   u'accident',
#   u'help',
#   u'bali',
#   u'saturday',
#   u'script',
#   u'film',
#   u'review',
#   u'cent',
#   u'rating',
#   u'review',
#   u'aggregation',
#   u'site',
#   u'part',
#   u'review',
#   u'downey',
#   u'actor',
#   u'heart',
#   u'soul',
#   u'film',
#   u'hour',
#   u'sag',
#   u'infinity',
#   u'war',
#   u'bang',
#   u'bit',
#   u'winner',
#   u'hand',
#   u'hemsworth',
#   u'thor',
#   u'hair',
#   u'paunch',
#   u'year',
#   u'destruction',
#   u'world',
#   u'pity',
#   u'beer',
#   u'actor',
#   u'sonali',
#   u'bendre',
#   u'grade',
#   u'cancer',
#   u'year',
#   u'source',
#   u'inspiration',
#   u'way',
#   u'battle',
#   u'cancer',
#   u'bffs',
#   u'season',
#   u'actor',
#   u'phase',
#   u'hair',
#   u'chemotherapy',
#   u'show',
#   u'dhupia',
#   u'host',
#   u'reason',
#   u'film',
#   u'hair',
#   u'sought',
#   u'actor',
#   u'bollywood',
#   u'part',
#   u'eminent',
#   u'filmmaker',
#   u'sanjay',
#   u'leela',
#   u'bhansali',
#   u'rajamouli',
#   u'film',
#   u'director',
#   u'bhansali',
#   u'rajamouli',
#   u'inshallah',
#   u'rrr',
#   u'search',
#   u'measure',
#   u'prevent',
#   u'killer',
#   u'authority',
#   u'bridge',
#   u'prevent',
#   u'entry',
#   u'exit',
#   u'island',
#   u'cast',
#   u'member',
#   u'miniseries',
#   u'vampire',
#   u'story',
#   u'dracula',
#   u'mark',
#   u'show',
#   u'partner',
#   u'feature',
#   u'john',
#   u'joanna',
#   u'actor',
#   u'jonathan',
#   u'dhawan',
#   u'catherine',
#   u'clive',
#   u'russell',
#   u'neat',
#   u'aussie',
#   u'superstar',
#   u'juice',
#   u'magazine',
#   u'asia',
#   u'curanderismo',
#   u'latino',
#   u'access',
#   u'health',
#   u'care',
#   u'university',
#   u'mexico',
#   u'professor',
#   u'conference',
#   u'albuquerque',
#   u'tale',
#   u'nothing',
#   u'curandero',
#   u'film',
#   u'connection',
#   u'healing',
#   u'sullivan',
#   u'chair',
#   u'study',
#   u'virginia',
#   u'commonwealth',
#   u'university',
#   u'scholar',
#   u'practice',
#   u'mexico',
#   u'movie',
#   u'promotion',
#   u'curanderismo',
#   u'something',
#   u'movie',
#   u'force',
#   u'election',
#   u'schedule',
#   u'force',
#   u'till',
#   u'election',
#   u'result',
#   u'year',
#   u'actor',
#   u'apart',
#   u'turner',
#   u'work',
#   u'wife',
#   u'series',
#   u'premiere',
#   u'time',
#   u'hop',
#   u'group',
#   u'mark',
#   u'world',
#   u'dance',
#   u'slot',
#   u'talent',
#   u'medal',
#   u'world',
#   u'hip',
#   u'hop',
#   u'dance',
#   u'championship',
#   u'accuser',
#   u'testify',
#   u'prosecutor',
#   u'weinstein',
#   u'case',
#   u'strategy',
#   u'area',
#   u'prosecutor',
#   u'year',
#   u'bill',
#   u'assault',
#   u'case',
#   u'medium',
#   u'letter',
#   u'week',
#   u'lawyer',
#   u'email',
#   u'woman',
#   u'relationship',
#   u'identify',
#   u'people',
#   u'assault',
#   u'release',
#   u'day',
#   u'role',
#   u'ayushmann',
#   u'debut',
#   u'film',
#   u'chaddha',
#   u'day',
#   u'kapoor',
#   u'sir',
#   u'play',
#   u'father',
#   u'trilogy',
#   u'franchise',
#   u'veteran',
#   u'harrison',
#   u'ford',
#   u'mark',
#   u'hamill',
#   u'action',
#   u'role',
#   u'kaif',
#   u'sort',
#   u'role',
#   u'ask',
#   u'kind',
#   u'work',
#   u'point',
#   u'career',
#   u'role',
#   u'affinity',
#   u'cool',
#   u'kind',
#   u'action',
#   u'role',
#   u'role',
#   u'actor',
#   u'word',
#   u'superhero',
#   u'movie',
#   u'actor',
#   u'portrayal',
#   u'bruce',
#   u'banner',
#   u'post',
#   u'hulk',
#   u'moment',
#   u'frame',
#   u'banner',
#   u'hulk',
#   u'picture',
#   u'sequence',
#   u'hulk',
#   u'ross',
#   u'time',
#   u'screen',
#   u'hulk',
#   u'mass',
#   u'actor',
#   u'family',
#   u'audience',
#   u'strength',
#   u'till',
#   u'date',
#   u'actor',
#   u'birthday',
#   u'ability',
#   u'switch',
#   u'work',
#   u'family',
#   u'interest',
#   u'excellent',
#   u'sense',
#   u'humour',
#   u'ability',
#   u'side',
#   u'situation',
#   u'yennai',
#   u'arindhaal',
#   u'work',
#   u'film',
#   u'winter',
#   u'war',
#   u'nicolas',
#   u'variety',
#   u'sonakshi',
#   u'sinha',
#   u'considers',
#   u'someone',
#   u'failure',
#   u'time',
#   u'hour',
#   u'leaner',
#   u'film',
#   u'hour',
#   u'film',
#   u'drunk',
#   u'chakraborty',
#   u'loser',
#   u'brother',
#   u'bridge',
#   u'distance',
#   u'chakraborty',
#   u'actor',
#   u'industry',
#   u'mediocre',
#   u'talent',
#   u'use',
#   u'range',
#   u'boyish',
#   u'broken',
#   u'matter',
#   u'lineup',
#   u'run',
#   u'friday',
#   u'lord',
#   u'scott',
#   u'disick',
#   u'family',
#   u'show',
#   u'man',
#   u'revenge',
#   u'rampage',
#   u'killer',
#   u'cop',
#   u'pursue',
#   u'chief',
#   u'suspect',
#   u'trailer',
#   u'devarattam',
#   u'promise',
#   u'lot',
#   u'action',
#   u'mass',
#   u'dialogue',
#   u'film',
#   u'crowd',
#   u'endgame',
#   u'record',
#   u'predecessor',
#   u'infinity',
#   u'war',
#   u'avenger',
#   u'infinity',
#   u'war',
#   u'film',
#   u'adaptation',
#   u'director',
#   u'story',
#   u'barroz',
#   u'gama',
#   u'treasure',
#   u'singer',
#   u'songwriter',
#   u'people',
#   u'magazine',
#   u'condition',
#   u'responsive',
#   u'james',
#   u'bond',
#   u'producer',
#   u'barbara',
#   u'broccoli',
#   u'gender',
#   u'swap',
#   u'character',
#   u'part',
#   u'male',
#   u'movie',
#   u'centre',
#   u'life',
#   u'story',
#   u'metro',
#   u'theatre',
#   u'film',
#   u'track',
#   u'avenger',
#   u'endgame',
#   u'dollar',
#   u'box',
#   u'office',
#   u'type',
#   u'audience',
#   u'day',
#   u'making',
#   u'film',
#   u'space',
#   u'touch',
#   u'spot',
#   u'audience',
#   u'feel',
#   u'entertainment',
#   u'iervolino',
#   u'statement',
#   u'hug',
#   u'bang',
#   u'theory',
#   u'star',
#   u'crew',
#   u'audience',
#   u'plenty',
#   u'hit',
#   u'comedy',
#   u'scientist',
#   u'part',
#   u'hour',
#   u'air',
#   u'mid',
#   u'heart',
#   u'cuoco',
#   u'fan',
#   u'warner',
#   u'comment',
#   u'series',
#   u'creator',
#   u'script',
#   u'bang',
#   u'theory',
#   u'heart',
#   u'forever',
#   u'movie',
#   u'help',
#   u'people',
#   u'life',
#   u'spirit',
#   u'fear',
#   u'researcher',
#   u'movie',
#   u'person',
#   u'trauma',
#   u'stage',
#   u'research',
#   u'author',
#   u'benefit',
#   u'movie',
#   u'post',
#   u'stress',
#   u'disorder',
#   u'question',
#   u'anything',
#   u'men',
#   u'trailer',
#   u'anything',
#   u'director',
#   u'team',
#   u'writer',
#   u'thriller',
#   u'capture',
#   u'mood',
#   u'country',
#   u'nightmare',
#   u'midst',
#   u'doctor',
#   u'treatment',
#   u'protocol',
#   u'plenty',
#   u'drama',
#   u'stem',
#   u'fear',
#   u'disease',
#   u'cure',
#   u'theron',
#   u'play',
#   u'gadot',
#   u'woman',
#   u'story',
#   u'pitch',
#   u'slap',
#   u'face',
#   u'sonakshi',
#   u'role',
#   u'arbaaz',
#   u'interview',
#   u'indianexpress',
#   u'thing',
#   u'feel',
#   u'minus',
#   u'impact',
#   u'cast',
#   u'bit',
#   u'section',
#   u'review',
#   u'star',
#   u'rating',
#   u'movie',
#   u'money',
#   u'analyst',
#   u'performance',
#   u'australia',
#   u'sonakshi',
#   u'failure',
#   u'sinha',
#   u'run',
#   u'box',
#   u'office',
#   u'past',
#   u'film',
#   u'kalank',
#   u'impress',
#   u'audience',
#   u'hemsworth',
#   u'tessa',
#   u'role',
#   u'trailer',
#   u'men',
#   u'actor',
#   u'marvel',
#   u'character',
#   u'thor',
#   u'valkyrie',
#   u'opportunity',
#   u'drop',
#   u'trailer',
#   u'film',
#   u'bodyguard',
#   u'actor',
#   u'bodyguard',
#   u'home',
#   u'secretary',
#   u'hawes',
#   u'site',
#   u'area',
#   u'influence',
#   u'india',
#   u'movie',
#   u'scene',
#   u'random',
#   u'guy',
#   u'home',
#   u'day',
#   u'film',
#   u'depict',
#   u'bit',
#   u'addition',
#   u'depression',
#   u'way',
#   u'everyone',
#   u'something',
#   u'character',
#   u'film',
#   u'support',
#   u'health',
#   u'sign',
#   u'weakness',
#   u'jim',
#   u'parson',
#   u'star',
#   u'genius',
#   u'sheldon',
#   u'cooper',
#   u'key',
#   u'fan',
#   u'attendance',
#   u'mother',
#   u'parson',
#   u'time',
#   u'winner',
#   u'role',
#   u'dance',
#   u'move',
#   u'shot',
#   u'parson',
#   u'character',
#   u'executive',
#   u'producer',
#   u'future',
#   ...],
#  'noun_corpus_3': [u'reversal',
#   u'income',
#   u'sector',
#   u'bank',
#   u'fee',
#   u'loan',
#   u'deal',
#   u'book',
#   u'borrower',
#   u'defaulter',
#   u'fee',
#   u'loan',
#   u'deal',
#   u'crack',
#   u'gill',
#   u'shift',
#   u'accounting',
#   u'practice',
#   u'income',
#   u'upfront',
#   u'gill',
#   u'way',
#   u'mean',
#   u'surprise',
#   u'future',
#   u'news',
#   u'investor',
#   u'love',
#   u'image',
#   u'uncertainty',
#   u'gain',
#   u'pain',
#   u'promise',
#   u'balance',
#   u'sheet',
#   u'sacrifice',
#   u'investor',
#   u'hope',
#   u'growth',
#   u'promise',
#   u'kapoor',
#   u'currency',
#   u'today',
#   u'china',
#   u'renminbi',
#   u'china',
#   u'ringgit',
#   u'rupiah',
#   u'dollar',
#   u'yen',
#   u'dollar',
#   u'index',
#   u'measure',
#   u'currency',
#   u'strength',
#   u'currency',
#   u'market',
#   u'gold',
#   u'price',
#   u'today',
#   u'factory',
#   u'activity',
#   u'data',
#   u'concern',
#   u'health',
#   u'economy',
#   u'risk',
#   u'spot',
#   u'gold',
#   u'ounce',
#   u'equity',
#   u'market',
#   u'today',
#   u'stock',
#   u'market',
#   u'mumbai',
#   u'india',
#   u'borrowing',
#   u'year',
#   u'period',
#   u'data',
#   u'bank',
#   u'firm',
#   u'source',
#   u'month',
#   u'route',
#   u'borrowing',
#   u'approval',
#   u'route',
#   u'rbi',
#   u'data',
#   u'january',
#   u'reserve',
#   u'chairman',
#   u'jerome',
#   u'interest',
#   u'rate',
#   u'time',
#   u'risk',
#   u'outlook',
#   u'inflation',
#   u'year',
#   u'yield',
#   u'trading',
#   u'wednesday',
#   u'bond',
#   u'yield',
#   u'price',
#   u'move',
#   u'direction',
#   u'year',
#   u'investor',
#   u'equity',
#   u'debt',
#   u'market',
#   u'benchmark',
#   u'index',
#   u'point',
#   u'pre',
#   u'trade',
#   u'year',
#   u'date',
#   u'tuesday',
#   u'economy',
#   u'signal',
#   u'official',
#   u'approach',
#   u'interest',
#   u'rate',
#   u'change',
#   u'public',
#   u'sector',
#   u'bank',
#   u'trading',
#   u'reserve',
#   u'bank',
#   u'india',
#   u'rbi',
#   u'bank',
#   u'corporation',
#   u'bank',
#   u'dhanlaxmi',
#   u'bank',
#   u'action',
#   u'pca',
#   u'framework',
#   u'condition',
#   u'monitoring',
#   u'corporation',
#   u'bank',
#   u'dhanlaxmi',
#   u'bank',
#   u'bank',
#   u'company',
#   u'rating',
#   u'business',
#   u'subsidiary',
#   u'slump',
#   u'sale',
#   u'capital',
#   u'market',
#   u'regulator',
#   u'security',
#   u'exchange',
#   u'board',
#   u'india',
#   u'press',
#   u'release',
#   u'rise',
#   u'month',
#   u'stock',
#   u'hasn',
#   u'gain',
#   u'year',
#   u'research',
#   u'business',
#   u'earnings',
#   u'rating',
#   u'business',
#   u'continue',
#   u'driver',
#   u'valuation',
#   u'gain',
#   u'month',
#   u'crisil',
#   u'stock',
#   u'trade',
#   u'time',
#   u'year',
#   u'earnings',
#   u'security',
#   u'misuse',
#   u'dark',
#   u'issue',
#   u'direction',
#   u'regulator',
#   u'order',
#   u'nse',
#   u'month',
#   u'security',
#   u'market',
#   u'disgorge',
#   u'profit',
#   u'nse',
#   u'location',
#   u'service',
#   u'interest',
#   u'position',
#   u'rupee',
#   u'reuters',
#   u'oil',
#   u'price',
#   u'rupee',
#   u'asia',
#   u'currency',
#   u'month',
#   u'agency',
#   u'input',
#   u'analyst',
#   u'volatility',
#   u'term',
#   u'head',
#   u'research',
#   u'kotak',
#   u'security',
#   u'rally',
#   u'phase',
#   u'tech',
#   u'parameter',
#   u'possibility',
#   u'consolidation',
#   u'resume',
#   u'downside',
#   u'nifty',
#   u'support',
#   u'sahaj',
#   u'agrawal',
#   u'security',
#   u'side',
#   u'banking',
#   u'profit',
#   u'booking',
#   u'banking',
#   u'share',
#   u'today',
#   u'profit',
#   u'rally',
#   u'index',
#   u'stock',
#   u'bank',
#   u'today',
#   u'pnb',
#   u'yes',
#   u'bank',
#   u'bank',
#   u'sbi',
#   u'loser',
#   u'ltd',
#   u'stake',
#   u'family',
#   u'cent',
#   u'share',
#   u'technology',
#   u'consideration',
#   u'purchase',
#   u'share',
#   u'promoter',
#   u'entity',
#   u'tech',
#   u'china',
#   u'manager',
#   u'index',
#   u'increase',
#   u'economist',
#   u'estimate',
#   u'data',
#   u'investor',
#   u'reserve',
#   u'bank',
#   u'policy',
#   u'review',
#   u'analyst',
#   u'rbi',
#   u'rate',
#   u'basis',
#   u'point',
#   u'fear',
#   u'slowdown',
#   u'growth',
#   u'prospect',
#   u'polycab',
#   u'india',
#   u'blockbuster',
#   u'debut',
#   u'today',
#   u'share',
#   u'share',
#   u'india',
#   u'ltd',
#   u'stock',
#   u'exchange',
#   u'issue',
#   u'price',
#   u'share',
#   u'response',
#   u'subscription',
#   u'time',
#   u'spicejet',
#   u'share',
#   u'day',
#   u'investor',
#   u'airline',
#   u'increase',
#   u'capacity',
#   u'jet',
#   u'woe',
#   u'spicejet',
#   u'share',
#   u'today',
#   u'jet',
#   u'share',
#   u'source',
#   u'management',
#   u'airline',
#   u'suspend',
#   u'operation',
#   u'debt',
#   u'airline',
#   u'board',
#   u'meeting',
#   u'today',
#   u'market',
#   u'dream',
#   u'week',
#   u'bank',
#   u'sentiment',
#   u'department',
#   u'forecast',
#   u'monsoon',
#   u'devang',
#   u'head',
#   u'equity',
#   u'centrum',
#   u'wealth',
#   u'management',
#   u'dubai',
#   u'rupee',
#   u'eye',
#   u'end',
#   u'sooner',
#   u'today',
#   u'event',
#   u'market',
#   u'dollar',
#   u'pre',
#   u'weakness',
#   u'bank',
#   u'strength',
#   u'oil',
#   u'barrel',
#   u'third',
#   u'surge',
#   u'flow',
#   u'bond',
#   u'country',
#   u'indicator',
#   u'day',
#   u'strength',
#   u'index',
#   u'pullback',
#   u'day',
#   u'stock',
#   u'market',
#   u'news',
#   u'market',
#   u'counterpart',
#   u'stoxx',
#   u'index',
#   u'country',
#   u'world',
#   u'index',
#   u'track',
#   u'share',
#   u'country',
#   u'day',
#   u'question',
#   u'tariff',
#   u'research',
#   u'analyst',
#   u'risk',
#   u'stock',
#   u'investor',
#   u'upside',
#   u'market',
#   u'resolution',
#   u'trade',
#   u'saga',
#   u'share',
#   u'gainer',
#   u'chip',
#   u'index',
#   u'index',
#   u'week',
#   u'index',
#   u'provider',
#   u'msci',
#   u'mainland',
#   u'share',
#   u'benchmark',
#   u'msci',
#   u'index',
#   u'asia',
#   u'share',
#   u'japan',
#   u'gain',
#   u'index',
#   u'year',
#   u'month',
#   u'market',
#   u'britain',
#   u'vote',
#   u'agreement',
#   u'union',
#   u'reserve',
#   u'hold',
#   u'policy',
#   u'meeting',
#   u'interest',
#   u'rate',
#   u'balance',
#   u'sheet',
#   u'reduction',
#   u'bank',
#   u'policy',
#   u'meeting',
#   u'week',
#   u'lack',
#   u'supply',
#   u'jakob',
#   u'crude',
#   u'market',
#   u'structure',
#   u'crude',
#   u'future',
#   u'month',
#   u'contract',
#   u'trading',
#   u'price',
#   u'month',
#   u'output',
#   u'state',
#   u'supply',
#   u'figure',
#   u'drop',
#   u'number',
#   u'oil',
#   u'rig',
#   u'month',
#   u'lending',
#   u'price',
#   u'support',
#   u'point',
#   u'rise',
#   u'oil',
#   u'production',
#   u'carsten',
#   u'analyst',
#   u'oil',
#   u'market',
#   u'drop',
#   u'opec',
#   u'output',
#   u'level',
#   u'demand',
#   u'group',
#   u'service',
#   u'tax',
#   u'construction',
#   u'project',
#   u'expectation',
#   u'budget',
#   u'property',
#   u'price',
#   u'measure',
#   u'budget',
#   u'news',
#   u'front',
#   u'realty',
#   u'firm',
#   u'profit',
#   u'consumer',
#   u'confidence',
#   u'estate',
#   u'sector',
#   u'equity',
#   u'investor',
#   u'sector',
#   u'foundation',
#   u'currency',
#   u'china',
#   u'renminbi',
#   u'rupiah',
#   u'dollar',
#   u'thai',
#   u'baht',
#   u'yen',
#   u'copper',
#   u'face',
#   u'disruption',
#   u'year',
#   u'strife',
#   u'extreme',
#   u'weather',
#   u'project',
#   u'delay',
#   u'production',
#   u'chilean',
#   u'miner',
#   u'executive',
#   u'nyrstar',
#   u'commodity',
#   u'trader',
#   u'control',
#   u'metal',
#   u'producer',
#   u'nyrstar',
#   u'restructuring',
#   u'creditor',
#   u'china',
#   u'economy',
#   u'quarter',
#   u'economy',
#   u'growth',
#   u'pace',
#   u'year',
#   u'reuters',
#   u'measure',
#   u'demand',
#   u'floor',
#   u'activity',
#   u'march',
#   u'india',
#   u'vix',
#   u'gauge',
#   u'correction',
#   u'yes',
#   u'security',
#   u'india',
#   u'vix',
#   u'index',
#   u'nse',
#   u'today',
#   u'today',
#   u'market',
#   u'month',
#   u'buying',
#   u'equity',
#   u'fitch',
#   u'rating',
#   u'cut',
#   u'gdp',
#   u'growth',
#   u'momentum',
#   u'listing',
#   u'office',
#   u'park',
#   u'reit',
#   u'way',
#   u'estate',
#   u'company',
#   u'portfolio',
#   u'mint',
#   u'november',
#   u'bengaluru',
#   u'estate',
#   u'developer',
#   u'corp',
#   u'sovereign',
#   u'wealth',
#   u'fund',
#   u'qatar',
#   u'investment',
#   u'authority',
#   u'asset',
#   u'reit',
#   u'structure',
#   u'security',
#   u'exchange',
#   u'board',
#   u'india',
#   u'sebi',
#   u'estate',
#   u'investment',
#   u'trust',
#   u'regulation',
#   u'reit',
#   u'regulation',
#   u'issue',
#   u'debt',
#   u'security',
#   u'equity',
#   u'amendment',
#   u'part',
#   u'government',
#   u'move',
#   u'revamp',
#   u'estate',
#   u'sector',
#   u'investor',
#   u'participation',
#   u'listing',
#   u'india',
#   u'event',
#   u'estate',
#   u'sector',
#   u'decade',
#   u'half',
#   u'subscription',
#   u'reit',
#   u'estate',
#   u'sector',
#   u'segment',
#   u'india',
#   u'reit',
#   u'asia',
#   u'shishir',
#   u'chairman',
#   u'director',
#   u'india',
#   u'support',
#   u'organization',
#   u'petroleum',
#   u'country',
#   u'extension',
#   u'member',
#   u'iraq',
#   u'support',
#   u'door',
#   u'novak',
#   u'delegate',
#   u'talk',
#   u'difference',
#   u'month',
#   u'stake',
#   u'meeting',
#   u'vienna',
#   u'june',
#   u'oil',
#   u'trader',
#   u'time',
#   u'shift',
#   u'supply',
#   u'need',
#   u'saudi',
#   u'russia',
#   u'founder',
#   u'commodity',
#   u'hedge',
#   u'fund',
#   u'philipp',
#   u'oil',
#   u'delay',
#   u'meeting',
#   u'point',
#   u'russia',
#   u'commit',
#   u'decision',
#   u'opec',
#   u'decade',
#   u'rivalry',
#   u'alliance',
#   u'russia',
#   u'cordial',
#   u'relationship',
#   u'feature',
#   u'men',
#   u'period',
#   u'cooperation',
#   u'oil',
#   u'market',
#   u'partnership',
#   u'cooperation',
#   u'investment',
#   u'polycab',
#   u'ipo',
#   u'april',
#   u'raise',
#   u'crore',
#   u'share',
#   u'range',
#   u'value',
#   u'company',
#   u'crore',
#   u'data',
#   u'stock',
#   u'exchange',
#   u'portion',
#   u'polycab',
#   u'ipo',
#   u'time',
#   u'portion',
#   u'investor',
#   u'time',
#   u'polycab',
#   u'year',
#   u'hotel',
#   u'operator',
#   u'chalet',
#   u'hotel',
#   u'share',
#   u'sale',
#   u'subscription',
#   u'interest',
#   u'time',
#   u'share',
#   u'embassy',
#   u'office',
#   u'park',
#   u'estate',
#   u'investment',
#   u'trust',
#   u'reit',
#   u'ipo',
#   u'subscription',
#   u'time',
#   u'interview',
#   u'way',
#   u'hindu',
#   u'business',
#   u'line',
#   u'newspaper',
#   u'reveals',
#   u'aggression',
#   u'compromise',
#   u'quality',
#   u'asset',
#   u'sign',
#   u'lender',
#   u'saw',
#   u'year',
#   u'loss',
#   u'core',
#   u'quarter',
#   u'fallout',
#   u'mistake',
#   u'risk',
#   u'bank',
#   u'mend',
#   u'dodgy',
#   u'loan',
#   u'share',
#   u'loan',
#   u'slippage',
#   u'decline',
#   u'insurance',
#   u'risk',
#   u'provision',
#   u'coverage',
#   u'leadership',
#   u'lender',
#   u'project',
#   u'borrower',
#   u'need',
#   u'pristine',
#   u'credit',
#   u'quality',
#   u'time',
#   u'bank',
#   u'cylinder',
#   u'grab',
#   u'business',
#   u'growth',
#   u'capital',
#   u'financing',
#   u'release',
#   u'bourse',
#   u'revise',
#   u'methodology',
#   u'index',
#   u'industry',
#   u'petroleum',
#   u'corporation',
#   u'index',
#   u'stock',
#   u'exchange',
#   u'monday',
#   u'share',
#   u'bse',
#   u'today',
#   u'promoter',
#   u'company',
#   u'stake',
#   u'crore',
#   u'transaction',
#   u'stock',
#   u'exchange',
#   u'monday',
#   u'purchaser',
#   u'fund',
#   u'fund',
#   u'family',
#   u'office',
#   u'wipro',
#   u'chairman',
#   u'others',
#   u'stake',
#   u'sale',
#   u'promoter',
#   u'stake',
#   u'sale',
#   u'proceeds',
#   u'debt',
#   u'creation',
#   u'asset',
#   u'cement',
#   u'power',
#   u'etc',
#   u'fmcg',
#   u'statement',
#   u'trader',
#   u'crude',
#   u'oil',
#   u'price',
#   u'fund',
#   u'inflow',
#   u'buying',
#   u'equity',
#   u'market',
#   u'fall',
#   u'mumbai',
#   u'rupee',
#   u'dollar',
#   u'forex',
#   u'trader',
#   u'holiday',
#   u'week',
#   u'exchange',
#   u'currency',
#   u'dollar',
#   u'day',
#   u'dollar',
#   u'output',
#   u'china',
#   u'steel',
#   u'output',
#   u'month',
#   u'year',
#   u'mill',
#   u'operation',
#   u'profit',
#   u'margin',
#   u'recovery',
#   u'stringent',
#   u'curb',
#   u'production',
#   u'country',
#   u'crackdown',
#   u'data',
#   u'china',
#   u'aluminium',
#   u'production',
#   u'basis',
#   u'month',
#   u'rate',
#   u'october',
#   u'winter',
#   u'curb',
#   u'industry',
#   u'price',
#   u'shanghai',
#   u'aluminium',
#   u'tonne',
#   u'day',
#   u'level',
#   u'december',
#   u'dollar',
#   u'currency',
#   u'basket',
#   u'currency',
#   u'greenback',
#   u'dollar',
#   u'commodity',
#   u'firm',
#   u'relationship',
#   u'fund',
#   u'generate',
#   u'signal',
#   u'shanghai',
#   u'blue',
#   u'chip',
#   u'loss',
#   u'percent',
#   u'fall',
#   u'dollar',
#   u'yuan',
#   u'percent',
#   u'percent',
#   u'msci',
#   u'index',
#   u'asia',
#   u'share',
#   u'japan',
#   u'percent',
#   u'week',
#   u'percent',
#   u'fall',
#   u'bourse',
#   u'mood',
#   u'bank',
#   u'growth',
#   u'everyone',
#   u'round',
#   u'policy',
#   u'stimulus',
#   u'investor',
#   u'economy',
#   u'president',
#   u'mario',
#   u'economy',
#   u'period',
#   u'weakness',
#   u'uncertainty',
#   u'rate',
#   u'bank',
#   u'round',
#   u'loan',
#   u'reversal',
#   u'week',
#   u'bank',
#   u'turn',
#   u'data',
#   u'australia',
#   u'sense',
#   u'market',
#   u'rupee',
#   u'dollar',
#   u'today',
#   u'trade',
#   u'deficit',
#   u'month',
#   u'oil',
#   u'price',
#   u'rupee',
#   u'trading',
#   u'dollar',
#   u'home',
#   u'currency',
#   u'dollar',
#   u'commodity',
#   u'investment',
#   u'firm',
#   u'oil',
#   u'production',
#   u'non',
#   u'producer',
#   u'brazil',
#   u'sea',
#   u'market',
#   u'sea',
#   u'mexico',
#   u'brazil',
#   u'continue',
#   u'note',
#   u'trade',
#   u'data',
#   u'refinitiv',
#   u'oil',
#   u'shipment',
#   u'sea',
#   u'mexico',
#   u'bpd',
#   u'decline',
#   u'crude',
#   u'production',
#   u'bpd',
#   u'year',
#   u'bpd',
#   u'making',
#   u'world',
#   u'oil',
#   u'producer',
#   u'president',
#   u'donald',
#   u'sunday',
#   u'thanks',
#   u'trade',
#   u'talk',
#   u'president',
#   u'risk',
#   u'sentiment',
#   u'equity',
#   u'market',
#   u'backdrop',
#   u'china',
#   u'trade',
#   u'talk',
#   u'news',
#   u'support',
#   u'government',
#   u'gold',
#   ...]}

# %%
def count_pos_sec(x,flag,sec):
    cnt = 0
    for word in x.split(' '):
        if word in noun_corpus_dict['noun_corpus_'+sec]:
            cnt = cnt + 1
    return cnt

# %%
processed_data_new['noun_cnt_0'] = processed_data_new['STORY_LEM2_noverbpron'].apply(lambda x: count_pos_sec(x,'noun','0'))
# processed_data_new['STORY_LEM2_noverbpron'].apply(lambda x: count_pos_sec(x,'noun','0'))

# %%
processed_data_new.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0           0             0
# 1           1             1
# 2           2             2
# 3           3             3
# 4           4             4
#
#                                                STORY  SECTION  \
# 0  painful huge reversal fee income  unheard amon...      3.0
# 1  formidable opposition alliance among congress ...      0.0
# 2  asian currencies trading lower today  south ko...      3.0
# 3  want answer question  click  answer   clicking...      1.0
# 4  global markets  gold prices edged today disapp...      3.0
#
#                                            STORY_LEM  \
# 0  painful huge reversal fee income unheard among...
# 1  formidable opposition alliance among congress ...
# 2  asian currency trading lower today south korea...
# 3  want answer question click answer clicking ans...
# 4  global market gold price edged today disappoin...
#
#                                           STORY_LEM2  \
# 0  painful huge reversal fee income unheard among...
# 1  formidable opposition alliance among congress ...
# 2  asian currency trading lower today south korea...
# 3  want answer question click answer clicking ans...
# 4  global market gold price edged today disappoin...
#
#                                STORY_LEM2_noverbpron  \
# 0  painful huge reversal fee income among private...
# 1  formidable opposition alliance among congress ...
# 2  asian currency lower today south korean china ...
# 3  answer question click answer answer user answe...
# 4  global market gold price today chinese factory...
#
#                                          noun_String  \
# 0   reversal income sector bank fee loan deal boo...
# 1   opposition alliance jharkhand mukti jharkhand...
# 2   currency today china china ringgit rupiah dol...
# 3   question click answer answer proceed answer v...
# 4   market gold price today factory activity data...
#
#                                           adj_String  \
# 0   painful huge fee unheard private structured u...
# 1                            formidable congress jmm
# 2   asian lower south korean renminbi malaysian i...
# 3   answer user ask neighbour many icon follow an...
# 4        global chinese global european weaker asian
#
#                         adv_String  noun_cnt_0  noun_cnt_1  noun_cnt_2  \
# 0   lender essentially rather well          45          45          38
# 1                              NaN          10           6           3
# 2           offshore however close          12          16          11
# 3               also reply already          28          31          31
# 4                              NaN          19          21          19
#
#    noun_cnt_3
# 0          48
# 1           3
# 2          17
# 3          20
# 4          22

# %%
processed_data_new['noun_cnt_1'] = processed_data_new['STORY_LEM2_noverbpron'].apply(lambda x: count_pos_sec(x,'noun','1'))
processed_data_new['noun_cnt_2'] = processed_data_new['STORY_LEM2_noverbpron'].apply(lambda x: count_pos_sec(x,'noun','2'))
processed_data_new['noun_cnt_3'] = processed_data_new['STORY_LEM2_noverbpron'].apply(lambda x: count_pos_sec(x,'noun','3'))

# %%
ready_data = processed_data_new

# %%
processed_data_new.to_csv(data_path + '/process_data4.csv')

# %%
# processed_data_new[split+2:]['SECTION'].unique

# %%
labels_train = ready_data[:split+2]['SECTION']

# %%
mapper = DataFrameMapper([
    (['noun_cnt_0','noun_cnt_1','noun_cnt_2','noun_cnt_3'],None),
    ('STORY_LEM2',CountVectorizer(binary=True, ngram_range=(0,1))),
#     ('noun_String',CountVectorizer(binary=True, ngram_range=(0,1))),
    ('STORY_LEM2',TfidfVectorizer(smooth_idf=True)),
#     ('adj_String',CountVectorizer(binary=True, ngram_range=(0,1))),
     ('noun_String',TfidfVectorizer(smooth_idf=True)),
#     ('adj_String',TfidfVectorizer(smooth_idf=True))
])

# %%
X_mapped = mapper.fit_transform(ready_data)
train_mapped,test_mapped = X_mapped[:split+2,:],X_mapped[split+2:,:]
X_train,X_test,Y_train,Y_test=train_test_split(train_mapped,labels_train,test_size=0.1,random_state=42)

# %%
from sklearn.naive_bayes import MultinomialNB,GaussianNB

# %%
model_naive_bayes = MultinomialNB()
model_naive_bayes.fit(X_train,Y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
Y_pred_nb_test = model_naive_bayes.predict(X_test)
print confusion_matrix(Y_pred_nb_test,Y_test)
print accuracy_score(Y_pred_nb_test,Y_test)
# Out:
# [[153   1  10   1]
#  [  4 276   9   4]
#  [  0   0 175   0]
#  [  0   0   0 118]]
# 0.9613848202396804

# %%
clf_neural = MLPClassifier(solver='adam', alpha=1e-5, hidden_layer_sizes=(300,200), random_state=1)
clf_neural.fit(X_train,Y_train)

# %%
Y_pred_neural_test = clf_neural.predict(X_test)
print confusion_matrix(Y_pred_neural_test,Y_test)
print accuracy_score(Y_pred_neural_test,Y_test)

# %%
pred_test_neural = clf_neural.predict(test_mapped)
pred_df = pd.DataFrame(pred_test_neural,columns=['SECTION'])
pred_df.to_csv(data_path+'/submission_nl17.csv',index=False)

# %%
model_naive_bayes.predict_proba(X_test)[0]
# Out:
# array([7.52709155e-30, 1.00000000e+00, 5.10148338e-29, 3.04408206e-30])

# %%
pred_prob = clf_neural.predict_proba(X_test)

# %%
pred_prob1 = clf_neural_lbfgs.predict_proba(X_test)

# %%
# max(pred_prob1[10])
pred_prob.shape
# Out:
# (751L, 4L)

# %%
print int(np.where(pred_prob1[10] == np.amax(pred_prob1[10]))[0])
# Out:
# 2

# %%
final_pred = np.empty([0,751],int)

# %%
for (i,j) in zip(pred_prob,pred_prob1):
    if np.max(i) > np.max(j):
        final_pred = np.append(final_pred,int(np.where(i == np.amax(i))[0]))
    else:
        final_pred = np.append(final_pred,int(np.where(j == np.amax(j))[0]))

# %%
final_pred.shape
# Out:
# (751L,)

# %%
print confusion_matrix(final_pred,Y_test)
print accuracy_score(final_pred,Y_test)
# Out:
# [[153   0   1   1]
#  [  2 275   0   1]
#  [  2   1 193   0]
#  [  0   1   0 121]]
# 0.9880159786950732

# %%
clf_neural_lbfgs = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(200,100), random_state=1) #200100 0.9853528628495339
clf_neural_lbfgs.fit(X_train,Y_train)
# Out:
# MLPClassifier(activation='relu', alpha=1e-05, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(200, 100), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=1, shuffle=True, solver='lbfgs', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %%
Y_pred_neural_lbfgs_test = clf_neural_lbfgs.predict(X_test)
print confusion_matrix(Y_pred_neural_lbfgs_test,Y_test)
print accuracy_score(Y_pred_neural_lbfgs_test,Y_test)
# Out:
# [[154   1   2   1]
#  [  1 275   0   1]
#  [  2   0 192   0]
#  [  0   1   0 121]]
# 0.9880159786950732

# %%
from xgboost import XGBClassifier

# %%
xgb = XGBClassifier(learning_rate=0.1, n_estimators=300, max_depth=6,
                        min_child_weight=3, gamma=0.2, subsample=0.6, colsample_bytree=1.0,
                        objective='multi:softprob', nthread=4, scale_pos_weight=1, seed=27)
xgb.fit(X_train,Y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1.0, gamma=0.2, learning_rate=0.1,
#        max_delta_step=0, max_depth=6, min_child_weight=3, missing=None,
#        n_estimators=300, n_jobs=1, nthread=4, objective='multi:softprob',
#        random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=27, silent=True, subsample=0.6)

# %%
Y_pred_xgb_test = xgb.predict(X_test)
print confusion_matrix(Y_pred_xgb_test,Y_test)
print accuracy_score(Y_pred_xgb_test,Y_test)
# Out:
# [[146   1   4   1]
#  [  4 265   2   5]
#  [  7   9 188   1]
#  [  0   2   0 116]]
# 0.952063914780293

# %%
xgb.predict_proba(X_test)
# Out:
# array([[6.9680988e-05, 9.9940670e-01, 4.6338572e-04, 6.0231043e-05],
#        [1.5743130e-03, 9.6106380e-01, 3.6740482e-02, 6.2134519e-04],
#        [6.4385858e-05, 7.4668112e-03, 3.7819678e-05, 9.9243098e-01],
#        ...,
#        [1.7505150e-02, 8.5047024e-01, 1.2503280e-01, 6.9918684e-03],
#        [1.8097039e-02, 6.2128139e-01, 4.7325224e-02, 3.1329635e-01],
#        [9.9996662e-01, 1.0311024e-05, 2.1462902e-05, 1.5575426e-06]],
#       dtype=float32)

# %%
del final
final = np.empty([0,751],int)

# %%
final.shape
# Out:
# (0L, 751L)

# %%
from scipy import stats

# %%
for i in range(0,len(Y_test)):
    final = np.append(final, int(stats.mode([Y_pred_nb_test[i],Y_pred_neural_test[i],Y_pred_xgb_test[i],Y_pred_neural_lbfgs_test[i]])[0]))

# %%
final
# Out:
# array([1, 1, 3, 2, 2, 1, 1, 2, 1, 1, 2, 1, 0, 0, 2, 1, 1, 2, 2, 3, 1, 1,
#        1, 1, 1, 2, 1, 0, 3, 2, 3, 2, 3, 0, 1, 2, 1, 2, 2, 2, 1, 0, 2, 1,
#        0, 3, 2, 2, 3, 3, 2, 0, 1, 2, 0, 1, 1, 0, 1, 3, 2, 1, 1, 1, 1, 0,
#        1, 3, 2, 0, 0, 1, 0, 1, 2, 1, 1, 2, 1, 3, 1, 3, 0, 1, 1, 0, 3, 1,
#        3, 3, 1, 0, 1, 1, 3, 0, 1, 1, 2, 2, 3, 2, 2, 2, 1, 0, 2, 0, 2, 1,
#        0, 0, 1, 3, 3, 2, 1, 1, 2, 3, 0, 0, 0, 2, 0, 3, 1, 0, 2, 0, 3, 2,
#        2, 2, 2, 1, 0, 3, 3, 1, 1, 1, 0, 0, 3, 2, 0, 1, 0, 3, 0, 1, 2, 2,
#        2, 1, 1, 1, 1, 1, 2, 2, 2, 1, 3, 0, 2, 3, 2, 1, 0, 0, 1, 2, 1, 3,
#        0, 1, 1, 3, 1, 3, 1, 2, 1, 2, 1, 1, 0, 1, 2, 2, 0, 3, 0, 3, 1, 0,
#        1, 1, 2, 2, 2, 2, 0, 1, 1, 1, 3, 2, 0, 1, 1, 0, 1, 2, 1, 2, 0, 1,
#        1, 1, 0, 3, 1, 3, 0, 1, 2, 1, 0, 2, 1, 3, 0, 1, 0, 0, 1, 2, 1, 3,
#        0, 0, 0, 2, 1, 2, 0, 0, 2, 1, 1, 2, 1, 1, 2, 3, 0, 1, 2, 1, 1, 2,
#        0, 1, 1, 0, 2, 0, 1, 1, 0, 1, 1, 1, 1, 1, 0, 2, 1, 1, 3, 2, 0, 1,
#        3, 1, 1, 1, 0, 2, 1, 3, 3, 1, 0, 1, 3, 3, 0, 0, 1, 2, 2, 0, 0, 1,
#        1, 2, 3, 3, 1, 1, 2, 2, 0, 1, 1, 1, 0, 0, 2, 1, 1, 1, 2, 3, 0, 0,
#        1, 3, 2, 1, 1, 1, 2, 1, 1, 0, 2, 2, 2, 1, 1, 0, 1, 2, 2, 2, 1, 1,
#        1, 3, 1, 1, 1, 1, 0, 3, 3, 3, 2, 2, 1, 0, 3, 1, 3, 2, 1, 3, 0, 1,
#        1, 0, 2, 1, 1, 1, 1, 1, 0, 2, 3, 3, 1, 1, 1, 2, 3, 1, 2, 1, 1, 3,
#        1, 0, 0, 1, 1, 3, 1, 1, 3, 3, 1, 2, 2, 3, 2, 0, 1, 0, 0, 2, 1, 0,
#        2, 1, 2, 1, 1, 3, 2, 0, 0, 2, 0, 2, 2, 3, 2, 3, 0, 3, 1, 3, 1, 0,
#        1, 3, 1, 1, 0, 2, 1, 3, 1, 0, 3, 2, 1, 2, 0, 2, 0, 1, 0, 2, 0, 3,
#        0, 1, 3, 1, 1, 1, 3, 2, 2, 0, 0, 3, 0, 3, 1, 2, 0, 1, 2, 0, 1, 2,
#        1, 0, 1, 0, 2, 0, 2, 1, 1, 0, 2, 3, 1, 3, 2, 3, 1, 2, 1, 1, 0, 3,
#        1, 1, 1, 1, 2, 2, 0, 1, 1, 3, 1, 2, 1, 2, 2, 3, 2, 1, 1, 2, 1, 1,
#        3, 2, 2, 1, 2, 1, 3, 1, 1, 0, 3, 2, 3, 3, 1, 0, 3, 3, 2, 3, 0, 1,
#        2, 0, 1, 2, 1, 0, 1, 0, 2, 2, 1, 2, 1, 3, 2, 3, 1, 1, 2, 2, 3, 1,
#        2, 2, 1, 0, 1, 3, 1, 0, 0, 0, 1, 3, 2, 0, 1, 0, 1, 1, 1, 0, 0, 2,
#        1, 3, 1, 0, 0, 2, 0, 2, 3, 1, 1, 1, 1, 2, 1, 3, 1, 2, 1, 2, 3, 2,
#        2, 0, 3, 2, 2, 3, 1, 1, 3, 0, 3, 2, 2, 3, 2, 3, 3, 1, 0, 2, 2, 2,
#        1, 1, 0, 2, 1, 1, 0, 0, 0, 3, 2, 2, 2, 3, 1, 0, 3, 1, 0, 0, 1, 1,
#        2, 3, 1, 0, 2, 2, 2, 2, 2, 0, 2, 0, 2, 2, 1, 1, 3, 1, 0, 0, 2, 3,
#        0, 1, 3, 2, 1, 3, 0, 1, 0, 2, 2, 2, 2, 0, 3, 0, 1, 3, 1, 0, 1, 0,
#        1, 3, 3, 0, 1, 2, 1, 3, 1, 1, 1, 2, 1, 0, 0, 1, 0, 1, 2, 1, 1, 0,
#        2, 2, 2, 2, 1, 1, 0, 1, 3, 0, 1, 2, 1, 3, 0, 3, 0, 2, 2, 2, 1, 1,
#        1, 1, 0])

# %%
print confusion_matrix(final,Y_test)
print accuracy_score(final,Y_test)
# Out:
# [[154   2   2   1]
#  [  3 271   3   2]
#  [  0   2 189   0]
#  [  0   2   0 120]]
# 0.9773635153129161
